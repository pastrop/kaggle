# %% [markdown]
# <a href="https://colab.research.google.com/github/pastrop/kaggle/blob/master/In_Conjunction_modified.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In Conjunction With
# ## Also can be called: In Conjunction With
#
# This is a script to find the concepts that are not synonyms, but things that are uniquely associated with a specific concept.  For instance "disappointed" would not return any of the concepts that are normally associated (frustrated, upset, sad), but return things like "screen" or "camera".

# %%
from luminoso_api import V5LuminosoClient as LuminosoClient
import csv
import numpy as np
import pack64
import statistics

# %%
project_url = "https://daylight.luminoso.com/app/projects/p87t862f/prt38rfw/highlights" # kf-demo

# %%
def split_url(project_url):
    workspace_id = project_url.strip('/').split('/')[5]
    project_id = project_url.strip('/').split('/')[6]
    api_url = '/'.join(project_url.strip('/').split('/')[:3]).strip('/') + '/api/v5'
    proj_api = '{}/projects/{}'.format(api_url, project_id)
    
    return(workspace_id, project_id, api_url, proj_api)


url_parts = split_url(project_url)

workspace_id = url_parts[0]
project_id = url_parts[1]
api_url = url_parts[2]
proj_apiv5 = url_parts[3]

print("api_url="+api_url)
print("url="+proj_apiv5)
print("prjid="+project_id)
print("workspace_id="+workspace_id)
# Out:
# api_url=https://daylight.luminoso.com/api/v5
# url=https://daylight.luminoso.com/api/v5/projects/prt38rfw
# prjid=prt38rfw
# workspace_id=p87t862f

# %%
client = LuminosoClient.connect(proj_apiv5)
client
# Out:
# <LuminosoClient for https://daylight.luminoso.com/api/v5/projects/prt38rfw/>

# %%
def read_documents_by_concepts(client, concepts, max_docs=0, filter=None):
    docs = []
    while True:
        if filter:
            result = client.get(
                "/docs", search={"texts": concepts}, filter=filter, limit=5000, offset=len(docs)
            )
        else:
            result = client.get(
                "/docs", search={"texts": concepts}, limit=5000, offset=len(docs)
            )

        if result["result"]:
            docs.extend(result["result"])
        else:
            break
        if 0 < max_docs <= len(docs):
            break
    return docs


def read_documents(client, max_docs=0, filter=None):
    docs = []
    while True:
        if filter:
            result = client.get(
                "/docs", filter=filter, limit=5000, offset=len(docs)
            )
        else:
            result = client.get(
                "/docs", limit=5000, offset=len(docs)
            )

        if result["result"]:
            docs.extend(result["result"])
        else:
            break
        if 0 < max_docs <= len(docs):
            break
    return docs

def write_documents(client,docs):
    offset = 0
    while offset<len(docs):
        end = min(len(docs),offset+1000)
        print("offs={},  end={},  len={}".format(offset,end,len(docs)))
        result = client.post('upload', docs=docs[offset:end])
        offset = end

# %%
concept = "disappointed"

# %%
# get the details on this specific concept so we can get the term value
cs = {"type": "specified", "concepts": [{"texts": [concept]}]}

concept_details = client.get("/concepts", concept_selector=cs)["result"][0]
concept_details
# Out:
# {'relevance': 377.0,
#  'texts': ['disappointed'],
#  'exact_term_ids': ['disappoint|en'],
#  'excluded_term_ids': [],
#  'vectors': ['XRyoFP4_NX41--TDAolAc-By9GwhBCw_eMCDP_tfAv2BW9ASwBtq8uX-RzBFF-afBsQ-Kc-0r-oN_ZWAaMA2L_Gs-NDAdI8-bA_lAB3_6LAJY-dg_az_Lb-8a_VGAZD_U___1A2R_e8-tFBSjAvpCyi-LE_KS_OyBSAAN4_jsAKC_Eq_erAL9_ET89v-1tAwFEAdBGR-ARD_k-NK9ffBlXA-s_xg_BnB6mDvvBzX-xe_KtCds_o4BS8AYABIJBl3_dYBsp9MjAI8--sAJNBzQ_wYAFdClk9j4BGCAGG9iJ-t7AnN_KXAeXCIk_94B5B-WX_k3-Uz_4p_GKAjO-v7Asl_pB9hz_9C-nO-YPAJzDWxCjTAyxARd-Su_JrAilBeeBm_ARw_m_BU4-or-9hBTR_jfAl9-kNAEzCz8BMV_ICDE7A8hBRd_jO_WY-b09ypCw0BV5CDFBUbDGO_0i_DJ-y0AS-A7CAOI-tb_Lw-g2CWY9_8-Dw9-A-JZ_Ht_qi-iJAQy9FV_bqBayCg3ARt_VvBf5AB9Amk_tTC6_Ac0_tV_3M-q_9lt-Wu9jp-zf-qN-bJAHh_27EHa_tw_M9CwC_N6AdIA4vAxM_hHAkTCrk-aN_cMCBDAnLAymCQDAqV-5EAl8_wGA96AJQCLWA6bBAjAT0_sfCVr_NYA7g_y7-mXBGo_pzAxZ_xiBrN-PL_bh_9W_FEDXp_TnANpCFdA6tA0fBEICrc-x4-XF_ou_uD-mg_Uw-v2AbBAfm_k1_Ya-7IAnoBAIAhL-5BBnSBGiAN-_NtAsOBDgAqP-Y5_dq_CH_lw_l1BpA_AK-nnBzPAtM9W0Anu--1Bx7-juAC9_fH_ni_enARqB-jBZPAbHAKk_5__N9AzoAA9_z5_uI_uC_5-'],
#  'name': 'disappointed'}

# %%
# get the term value on the concept we are searching
concept_term = concept_details['exact_term_ids'][0]
concept_term
# Out:
# 'disappoint|en'

# %%
# get the concepts related to the concept we are searching
# this is so we know which concepts are not interesting
cs = {"type": "related", "search_concept": {"texts": [concept]}, "limit": 50}
related_concepts = client.get("/concepts", concept_selector=cs)["result"]

# %%
related_concepts[10]
# Out:
# {'relevance': 22.0,
#  'match_score': 0.6212236285209656,
#  'texts': ['pleasantly surprised'],
#  'exact_term_ids': ['pleasantly|en surprise|en'],
#  'excluded_term_ids': [],
#  'vectors': ['XXmeCU9I9C5596DEBHx_ukCJaFm__06A4_CaU8xG_78_o2AS4AI9_II_0qCCOCAtBhO_r5BE39VO_fZCVhCDZA7T_1--SB-Jn_wc-Af-uO9T1BkP-Vd_bDBIYAhG_ZB-thAzkAj9_mwA-rAY2BMVB1z9iUAMG9dPCIh-X2BVE98b-waBKj-xA-FO9smAlSBhJB3lAcJ-fjBskBoL-eCA44A-B_ayAlEAoZApq-hs_liAAiB5J9FK_Q7Br3AorA6rBvL-cJ-mmAh4AcpBZ3_-wAbfAQVCoz_HIAP7--u-bfBjt_j-APq955AdNAv5BSqAWa-lPAAJBMkAdWBDS_w7BJRAM__oTAIe-bR_5gANDAwCAgs_pq_uo_5PAPF_8lBFr_2g-1UAY3A4vAKdBIQ_sKBYMAJ2_N-_q0CRPBdu_fC_PZAO2ADA_-UAdx_rjAwWA4I_u-AYz_6GAS__NbAdr_zaAeZAyoAPN_nzBHZ_J-_vOATDAnV_rlAMV_rDBH-AdSAKF_qk_cLAirBaBAYC_Hi_kP-a1_WVAvjBO7_l8_thAYlAAZ_hQ_Xd_87_Vj-6c_Xe_Xw_eHAhk_uNAD2A_kAmw_J7AD8AC2A0AAL_Bk8AfyAPu_2gANiAKkAWbAWi_a4_OVAyyAYg_0X_nRA6m_-kBHiAAi_6NASTAFN_0_Am5_gGA98AnP_A2_tzA1e_26AtMAqxAEOAtWAUw_oM_4yAW9_mkAVBAiTACJ_5lAjWAZPAEE_NDARZAEt_voAmMAqhAaxAp1A7YBSSBDDAt2Avo_4VAqZAPcArI_Y1AmDACT_uC_ptBK0_oR_5TAMIApa_2HAvUAOGAvJAi-AGu_e_AV-Aw7Am3AvcA37AD9AIY_qk_7aAvQATFAUN_18ANd_qs'],
#  'name': 'pleasantly surprised'}

# %%
# convert the list to a list of term_ids
related_term_ids = [c['exact_term_ids'][0] for c in related_concepts]
related_term_ids
# Out:
# ['disappoint|en',
#  'dissapointed|en',
#  'disappointment|en',
#  'dismay|en',
#  'upset|en',
#  'letdown|en',
#  'surprise|en',
#  'frustrate|en',
#  'mislead|en',
#  'impress|en',
#  'pleasantly|en surprise|en',
#  'deceive|en',
#  'sad|en',
#  'excite|en',
#  'discourage|en',
#  'bummer|en',
#  'unhappy|en',
#  'embarrass|en',
#  'astonish|en',
#  'disillusion|en',
#  'unimpressed|en',
#  'disapointed|en',
#  'offend|en',
#  'fascinate|en',
#  'tempt|en',
#  'admit|en',
#  'shock|en',
#  'needless|en',
#  'fortunately|en',
#  'not|en impress|en',
#  'not|en fault|en',
#  'bother|en',
#  'suprise|en',
#  'unfortunately|en',
#  'satisfy|en',
#  'proud|en',
#  'sadly|en',
#  'doubt|en',
#  'baffle|en',
#  'not|en stand|en',
#  'ruin|en',
#  'pitiful|en',
#  'sincerely|en',
#  'await|en',
#  'depress|en',
#  'sorely|en',
#  'dissatisfy|en',
#  'irk|en',
#  'hopeful|en',
#  'not|en rate|en']

# %%
# get the documents for the concept
related_docs = read_documents_by_concepts(client, [concept])
len(related_docs)
# Out:
# 1037

# %%
cs = {"type": "top", "limit": 100}
top_concepts_100 = client.get("/concepts", concept_selector=cs)["result"]
top_concepts_100 = [tc['exact_term_ids'][0] for tc in top_concepts_100]
top_concepts_100
# Out:
# ['kindle|en',
#  'amazon|en',
#  'tablet|en',
#  'kindle|en fire|en',
#  'app|en',
#  'kindle|en fire|en hd|en',
#  'purchase|en',
#  'ipad|en',
#  'device|en',
#  'download|en',
#  'hd|en',
#  'screen|en',
#  'buy|en',
#  'fire|en hd|en',
#  'ad|en',
#  'speaker|en',
#  'disappoint|en',
#  'charger|en',
#  'amazon|en prime|en',
#  'laptop|en',
#  'recommend|en',
#  'reader|en',
#  'kindle|en fire|en hd|en 7|en',
#  'wifi|en',
#  'product|en',
#  'android|en',
#  'upgrade|en',
#  'charge|en',
#  'email|en',
#  'skype|en',
#  'movie|en',
#  'battery|en life|en',
#  'load|en',
#  'watch|en movie|en',
#  'display|en',
#  'button|en',
#  'gift|en',
#  'kindle|en hd|en',
#  'book|en',
#  'cloud|en',
#  'netflix|en',
#  'item|en',
#  'connect|en',
#  'love|en kindle|en',
#  'feature|en',
#  'ipad|en mini|en',
#  'annoy|en',
#  'complaint|en',
#  'plug|en',
#  'keyboard|en',
#  'battery|en',
#  'update|en',
#  'cheap|en',
#  'camera|en',
#  'read|en',
#  'ship|en',
#  'highly|en recommend|en',
#  'love|en kindle|en fire|en hd|en',
#  'nexus|en 7|en',
#  'new|en kindle|en',
#  'fast|en',
#  'stream|en',
#  'sound|en',
#  'christmas|en',
#  'wi-fi|en',
#  'audio|en',
#  'read|en book|en',
#  'carousel|en',
#  'impress|en',
#  'enjoy|en',
#  'magazine|en',
#  'web|en',
#  'color|en',
#  'replace|en',
#  'excellent|en',
#  'apple|en',
#  'iphone|en',
#  'user|en',
#  'customer|en',
#  'browser|en',
#  'advertise|en',
#  'option|en',
#  'con|en',
#  'original|en kindle|en fire|en',
#  'easy|en',
#  'awesome|en',
#  'price|en',
#  'browse|en',
#  'graphics|en',
#  'install|en',
#  'old|en kindle|en',
#  'pro|en',
#  'flash|en',
#  'nook|en',
#  'review|en',
#  'customer|en service|en',
#  'compare|en',
#  'improvement|en',
#  'computer|en',
#  'new|en kindle|en fire|en hd|en']

# %%
related_docs[0]
# Out:
# {'text': 'I was so excited that my husband bought this for me for Christmas, I couldn\'t wait to get it! I researched and asked everyone if I should get this or the Nook and hands down it was the Kindle Fire Hd. I am excited for all that it has to offer including the music and movies for when I\'m up north, there are endless possiblities!! I think unfortunately, I got a "glitchy" one. I have called Amazon 2x regarding problems so far and if I have to call again, I will return it! I am so upset. I absolutely love the fact that I have my books wherever I go, that\'s my favorite thing. I am a major reader, but then to be able to go on Facebook or the web is just so awesome! The books for readers out there are just amazing and Amazon has an awesome library to choose from! How can you get better than that? I am so upset though because I do not think that the "glitches" I have are due to user error. I was at the library downloading my books, it kept stopping midway and then when it was done, I had downloaded the book and it saved 5 times. While talking to a librarian friend, I showed her that when I was on Facebook I would hardly touch the screen it would go off onto another page that I never directed it to. When scrolling my newsfeed, it would do the same thing and the most frustrating is when I post and want to go back where I was, it would start from the beginning again and again and again. SO frustrating!! Makes it so I don\'t even want to go on FB with my Kindle! I also showed her the downloaded books and she said hers never did that and she loves her Kindle. I have to use my husband\'s computer to even enjoy FB. Why have my Kindle then? He bought me it so I can do what I want, when I want, and not be on his computer. So he feels bad that I\'m not happy. I think it\'s a glitch too because while reading my books, it will make turning pages difficult at times and others, way to easy. My bookmark doesn\'t work either, it will start either a few pages before or after when I stopped reading. I know this is a great item because everyone I asked absolutely loves theirs and it comes highly recommended, that\'s why I chose it. It\'s just breaking my heart, I am so disappointed, if it continues though, sadly, I will be returning mine. :(',
#  'metadata': [{'name': 'date',
#    'type': 'date',
#    'value': '2013-01-08T00:00:00.000Z'},
#   {'name': 'rating', 'type': 'score', 'value': 2}],
#  'title': 'Frustrated and sad',
#  'terms': [{'term_id': 'excite|en', 'start': 9, 'end': 16},
#   {'term_id': 'husband|en', 'start': 25, 'end': 32},
#   {'term_id': 'buy|en', 'start': 33, 'end': 39},
#   {'term_id': 'christmas|en', 'start': 56, 'end': 65},
#   {'term_id': 'not|en wait|en', 'start': 69, 'end': 82},
#   {'term_id': 'get|en', 'start': 86, 'end': 89},
#   {'term_id': 'research|en', 'start': 96, 'end': 106},
#   {'term_id': 'ask|en', 'start': 111, 'end': 116},
#   {'term_id': 'get|en', 'start': 138, 'end': 141},
#   {'term_id': 'nook|en', 'start': 154, 'end': 158},
#   {'term_id': 'hand|en', 'start': 163, 'end': 168},
#   {'term_id': 'kindle|en fire|en hd|en', 'start': 185, 'end': 199},
#   {'term_id': 'excite|en', 'start': 206, 'end': 213},
#   {'term_id': 'offer|en', 'start': 237, 'end': 242},
#   {'term_id': 'include|en', 'start': 243, 'end': 252},
#   {'term_id': 'music|en', 'start': 257, 'end': 262},
#   {'term_id': 'movie|en', 'start': 267, 'end': 273},
#   {'term_id': 'north|en', 'start': 290, 'end': 295},
#   {'term_id': 'endless|en', 'start': 307, 'end': 314},
#   {'term_id': 'possiblities|en', 'start': 315, 'end': 327},
#   {'term_id': 'think|en', 'start': 332, 'end': 337},
#   {'term_id': 'unfortunately|en', 'start': 338, 'end': 351},
#   {'term_id': 'get|en', 'start': 355, 'end': 358},
#   {'term_id': 'glitchy|en', 'start': 361, 'end': 370},
#   {'term_id': 'call|en amazon|en', 'start': 383, 'end': 396},
#   {'term_id': '2x|en', 'start': 397, 'end': 399},
#   {'term_id': 'regard|en', 'start': 400, 'end': 409},
#   {'term_id': 'problem|en', 'start': 410, 'end': 418},
#   {'term_id': 'far|en', 'start': 422, 'end': 425},
#   {'term_id': 'call|en', 'start': 443, 'end': 447},
#   {'term_id': 'return|en', 'start': 462, 'end': 468},
#   {'term_id': 'upset|en', 'start': 481, 'end': 486},
#   {'term_id': 'absolutely|en love|en', 'start': 490, 'end': 505},
#   {'term_id': 'fact|en', 'start': 510, 'end': 514},
#   {'term_id': 'book|en', 'start': 530, 'end': 535},
#   {'term_id': 'go|en', 'start': 547, 'end': 549},
#   {'term_id': 'favorite|en', 'start': 561, 'end': 569},
#   {'term_id': 'major|en', 'start': 584, 'end': 589},
#   {'term_id': 'reader|en', 'start': 590, 'end': 596},
#   {'term_id': 'able|en', 'start': 613, 'end': 617},
#   {'term_id': 'go|en', 'start': 621, 'end': 623},
#   {'term_id': 'facebook|en', 'start': 627, 'end': 635},
#   {'term_id': 'web|en', 'start': 643, 'end': 646},
#   {'term_id': 'awesome|en', 'start': 658, 'end': 665},
#   {'term_id': 'book|en', 'start': 671, 'end': 676},
#   {'term_id': 'reader|en', 'start': 681, 'end': 688},
#   {'term_id': 'amaze|en', 'start': 708, 'end': 715},
#   {'term_id': 'amazon|en', 'start': 720, 'end': 726},
#   {'term_id': 'awesome|en', 'start': 734, 'end': 741},
#   {'term_id': 'library|en', 'start': 742, 'end': 749},
#   {'term_id': 'choose|en', 'start': 753, 'end': 759},
#   {'term_id': 'get|en', 'start': 778, 'end': 781},
#   {'term_id': 'better|en', 'start': 782, 'end': 788},
#   {'term_id': 'upset|en', 'start': 808, 'end': 813},
#   {'term_id': 'not|en think|en', 'start': 834, 'end': 843},
#   {'term_id': 'glitch|en', 'start': 853, 'end': 863},
#   {'term_id': 'due|en', 'start': 875, 'end': 878},
#   {'term_id': 'user|en', 'start': 882, 'end': 886},
#   {'term_id': 'error|en', 'start': 887, 'end': 892},
#   {'term_id': 'library|en', 'start': 907, 'end': 914},
#   {'term_id': 'download|en book|en', 'start': 915, 'end': 935},
#   {'term_id': 'keep|en', 'start': 940, 'end': 944},
#   {'term_id': 'stop|en', 'start': 945, 'end': 953},
#   {'term_id': 'midway|en', 'start': 954, 'end': 960},
#   {'term_id': 'download|en book|en', 'start': 994, 'end': 1013},
#   {'term_id': 'save|en', 'start': 1021, 'end': 1026},
#   {'term_id': 'time|en', 'start': 1029, 'end': 1034},
#   {'term_id': 'talk|en', 'start': 1042, 'end': 1049},
#   {'term_id': 'librarian|en', 'start': 1055, 'end': 1064},
#   {'term_id': 'friend|en', 'start': 1065, 'end': 1071},
#   {'term_id': 'show|en', 'start': 1075, 'end': 1081},
#   {'term_id': 'facebook|en', 'start': 1105, 'end': 1113},
#   {'term_id': 'hardly|en', 'start': 1122, 'end': 1128},
#   {'term_id': 'touch|en screen|en', 'start': 1129, 'end': 1145},
#   {'term_id': 'go|en', 'start': 1155, 'end': 1157},
#   {'term_id': 'page|en', 'start': 1175, 'end': 1179},
#   {'term_id': 'not|en direct|en', 'start': 1187, 'end': 1201},
#   {'term_id': 'scroll|en', 'start': 1214, 'end': 1223},
#   {'term_id': 'newsfeed|en', 'start': 1227, 'end': 1235},
#   {'term_id': 'most|en', 'start': 1272, 'end': 1276},
#   {'term_id': 'frustrate|en', 'start': 1277, 'end': 1288},
#   {'term_id': 'post|en', 'start': 1299, 'end': 1303},
#   {'term_id': 'want|en', 'start': 1308, 'end': 1312},
#   {'term_id': 'go|en back|en', 'start': 1316, 'end': 1323},
#   {'term_id': 'start|en', 'start': 1346, 'end': 1351},
#   {'term_id': 'begin|en', 'start': 1361, 'end': 1370},
#   {'term_id': 'frustrate|en', 'start': 1401, 'end': 1412},
#   {'term_id': 'make|en', 'start': 1415, 'end': 1420},
#   {'term_id': 'not|en want|en', 'start': 1429, 'end': 1444},
#   {'term_id': 'go|en', 'start': 1448, 'end': 1450},
#   {'term_id': 'fb|en', 'start': 1454, 'end': 1456},
#   {'term_id': 'kindle|en', 'start': 1465, 'end': 1471},
#   {'term_id': 'show|en', 'start': 1480, 'end': 1486},
#   {'term_id': 'download|en book|en', 'start': 1495, 'end': 1511},
#   {'term_id': 'say|en', 'start': 1520, 'end': 1524},
#   {'term_id': 'love|en kindle|en', 'start': 1553, 'end': 1569},
#   {'term_id': 'use|en', 'start': 1581, 'end': 1584},
#   {'term_id': 'husband|en', 'start': 1588, 'end': 1595},
#   {'term_id': 'computer|en', 'start': 1598, 'end': 1606},
#   {'term_id': 'even|en', 'start': 1610, 'end': 1614},
#   {'term_id': 'enjoy|en', 'start': 1615, 'end': 1620},
#   {'term_id': 'fb|en', 'start': 1621, 'end': 1623},
#   {'term_id': 'kindle|en', 'start': 1637, 'end': 1643},
#   {'term_id': 'buy|en', 'start': 1653, 'end': 1659},
#   {'term_id': 'want|en', 'start': 1685, 'end': 1689},
#   {'term_id': 'want|en', 'start': 1698, 'end': 1702},
#   {'term_id': 'not|en computer|en', 'start': 1708, 'end': 1730},
#   {'term_id': 'feel|en', 'start': 1738, 'end': 1743},
#   {'term_id': 'bad|en', 'start': 1744, 'end': 1747},
#   {'term_id': 'not|en happy|en', 'start': 1757, 'end': 1766},
#   {'term_id': 'think|en', 'start': 1770, 'end': 1775},
#   {'term_id': 'glitch|en', 'start': 1783, 'end': 1789},
#   {'term_id': 'read|en book|en', 'start': 1808, 'end': 1824},
#   {'term_id': 'make|en', 'start': 1834, 'end': 1838},
#   {'term_id': 'turn|en', 'start': 1839, 'end': 1846},
#   {'term_id': 'page|en', 'start': 1847, 'end': 1852},
#   {'term_id': 'difficult|en', 'start': 1853, 'end': 1862},
#   {'term_id': 'time|en', 'start': 1866, 'end': 1871},
#   {'term_id': 'easy|en', 'start': 1891, 'end': 1895},
#   {'term_id': 'bookmark|en', 'start': 1900, 'end': 1908},
#   {'term_id': 'not|en work|en', 'start': 1909, 'end': 1921},
#   {'term_id': 'start|en', 'start': 1938, 'end': 1943},
#   {'term_id': 'page|en', 'start': 1957, 'end': 1962},
#   {'term_id': 'stop|en', 'start': 1986, 'end': 1993},
#   {'term_id': 'read|en', 'start': 1994, 'end': 2001},
#   {'term_id': 'know|en', 'start': 2005, 'end': 2009},
#   {'term_id': 'great|en', 'start': 2020, 'end': 2025},
#   {'term_id': 'item|en', 'start': 2026, 'end': 2030},
#   {'term_id': 'ask|en', 'start': 2050, 'end': 2055},
#   {'term_id': 'absolutely|en love|en', 'start': 2056, 'end': 2072},
#   {'term_id': 'come|en', 'start': 2087, 'end': 2092},
#   {'term_id': 'highly|en recommend|en', 'start': 2093, 'end': 2111},
#   {'term_id': 'choose|en', 'start': 2126, 'end': 2131},
#   {'term_id': 'break|en', 'start': 2146, 'end': 2154},
#   {'term_id': 'heart|en', 'start': 2158, 'end': 2163},
#   {'term_id': 'disappoint|en', 'start': 2173, 'end': 2185},
#   {'term_id': 'continue|en', 'start': 2193, 'end': 2202},
#   {'term_id': 'sadly|en', 'start': 2211, 'end': 2216},
#   {'term_id': 'return|en', 'start': 2228, 'end': 2237}],
#  'fragments': [{'term_id': 'kindle|en', 'start': 185, 'end': 191},
#   {'term_id': 'kindle|en fire|en', 'start': 185, 'end': 196},
#   {'term_id': 'fire|en', 'start': 192, 'end': 196},
#   {'term_id': 'fire|en hd|en', 'start': 192, 'end': 199},
#   {'term_id': 'hd|en', 'start': 197, 'end': 199},
#   {'term_id': 'call|en', 'start': 383, 'end': 389},
#   {'term_id': 'amazon|en', 'start': 390, 'end': 396},
#   {'term_id': 'absolutely|en', 'start': 490, 'end': 500},
#   {'term_id': 'love|en', 'start': 501, 'end': 505},
#   {'term_id': 'download|en', 'start': 915, 'end': 926},
#   {'term_id': 'book|en', 'start': 930, 'end': 935},
#   {'term_id': 'download|en', 'start': 994, 'end': 1004},
#   {'term_id': 'book|en', 'start': 1009, 'end': 1013},
#   {'term_id': 'touch|en', 'start': 1129, 'end': 1134},
#   {'term_id': 'screen|en', 'start': 1139, 'end': 1145},
#   {'term_id': 'go|en', 'start': 1316, 'end': 1318},
#   {'term_id': 'back|en', 'start': 1319, 'end': 1323},
#   {'term_id': 'download|en', 'start': 1495, 'end': 1505},
#   {'term_id': 'book|en', 'start': 1506, 'end': 1511},
#   {'term_id': 'love|en', 'start': 1553, 'end': 1558},
#   {'term_id': 'kindle|en', 'start': 1563, 'end': 1569},
#   {'term_id': 'read|en', 'start': 1808, 'end': 1815},
#   {'term_id': 'book|en', 'start': 1819, 'end': 1824},
#   {'term_id': 'absolutely|en', 'start': 2056, 'end': 2066},
#   {'term_id': 'love|en', 'start': 2067, 'end': 2072},
#   {'term_id': 'highly|en', 'start': 2093, 'end': 2099},
#   {'term_id': 'recommend|en', 'start': 2100, 'end': 2111}],
#  'vector': 'XdH5I69AjLBiWA2k9LTCZ--sHBmnAmkALxClBAtqBd8_3DAhu_2HA87ADUA2vAmBCBi_HJAmf_FDAD4A4ABKTBJO_Eq_vrA1iAbz_ZpAGL_NnA5R_eEAxs_pg_SpAr9AFMBjwAcZ_2v_53AAuAYh_Gs_tVALvASVAM5_4uAp5A4DADiAEyAK6_QG_ZGAUk_0vBUh_6CAMxA6i_ko_yLAE_Aje_04BDqAcOAa7_rQAW1_3RA_U_SHAHs_3I_2sAMPARwAQK_ebAmuAD-_1yAmkAF3_3tARmAIRALnAJcANb_-o_bq_w2AX4_tsA4z_9iADtAbaAHwAYZASNAfzAXMA53BMi_9xAG4AGsAg6A7_AmQAfCAxYAkd_-oAQP_wXBD-__4_1dAIXAbeAKjAAfAPOAPlAZRAO4AY5AG6AcjASLAKoAjcAS4AB0ATU_4-ADqAG9_8aAkB_rsAL1AbbAQ6AAuAaIAeyAmlAJTAIK_uZADSAypAvI_84_8YAL0AyDAjwAb4_pdALk_13AbqAP8ALn__R_2B_sEBK3Ak__33AyUAkFAo3ABsAZuAFhAPM_-Z_Z4_f3_6dAnnAUb_5WAjwADn_yjALoAo1Am6AOPASbAG3AdzANuAJo_fNAJSANpAH_AJbAWhABV_8v_vZAIfAAGAB_AYj_-7_sRAi4_tTAcLAJ4AflAT1_1hAMqAbBAHE_unAkQAdI_8mAAe_9VAoFAD6AG1_6xAStAL8AIOAHLAQy_5qACAAh2AaEAn1_8y_0QACoAIw_3GBSEAA5AqLAlkANXAPrAQH_-IALE_unA6pAOAAAqAciALPAPOAg5BapAOLAhMAacAxqAfTAGwAANAPPAZpAXzAUBAXxAJEACh_4lAJHAjmAYUAhsAPaASX_72',
#  'match_score': 2.313361167907715,
#  'doc_id': 'uuid-8da0c53ad786411c8dbbb5353e2871f6'}

# %%
# given a list of locations, find the closest
def find_closest_proximity(term_loc, related_locations):
    if len(related_locations)<=0:
        return None
    proximity = related_locations[0] - term_loc
    for cur_loc in related_locations:
        prox_temp = cur_loc - term_loc
        if abs(prox_temp)<abs(proximity):
            proximity = prox_temp
    return proximity

# in_conjunction_with_raw
# Description: Find the concepts not directly associated with the concept_term_id
#              but in the same documents as concept_term_id and it's conceptual matches.
#              _raw takes raw concept lists
#
# Parameters:
#   docs: The documents to you want to measure
#   concept_term_id: The concept you are looking for conjunctions: disappoint|en
#   related_term_ids: The list of concept terms associated with concept_term_id 
#        ['disappoint|en',
#         'dissapointed|en',
#         'disappointment|en',
#         'etc']
#   top_concept_filter: The list of top concepts to filter by.
#       ['kindle|en',
#        'amazon|en',
#        'tablet|en',]
def in_conjunction_with_raw(docs, concept_term_id, related_terms_ids, top_concept_filter=None):
    in_conjunctions = {}

    for d in docs:
        exact_match_locations = []
        conceptual_match_locations = []
        doc_in_conjunctions = {}
        for t in d['terms']:
            # only add terms if they are in the top_concept_filter
            # print("checking: t {} in tcf {}".format(t['term_id'],t['term_id'] in top_concept_filter))
            if (not top_concept_filter) or (t['term_id'] in top_concept_filter):
                if concept_term_id == t['term_id']:
                    # use to calculate proximity of exact match
                    exact_match_locations.append(t['start']) 
                elif t['term_id'] in related_term_ids:
                    # use to calculate proximity of conceptual match
                    conceptual_match_locations.append(t['start']) 
                else:
                    #print("addining term: {} at {}".format(t['term_id'], t['start']))
                    # found a non-exact/conceptual concept
                    if t['term_id'] in doc_in_conjunctions:
                        # add the location to the list
                        doc_in_conjunctions[t['term_id']]['locations'].append(t['start'])
                    else:
                        doc_in_conjunctions[t['term_id']] = {
                            'term_id': t['term_id'],
                            'locations': [t['start']]  # use this to calculate the proximity to exact/conceptual match
                        }
        # calculate the proximity to exact and conceptual matches
        # keep those values as a list so average can be calculated next
        for k2,d2 in doc_in_conjunctions.items():
            total_exact_loc = 0
            total_conceptual_loc = 0
            for loc in d2['locations']:
                loc2 = find_closest_proximity(loc, exact_match_locations)
                if loc2:
                    total_exact_loc += loc2
                loc2 = find_closest_proximity(loc, conceptual_match_locations)
                if loc2:
                    total_conceptual_loc += loc2
            if (len(d2['locations']))>0:
                d2['in_conjunction_with_exact_average'] = total_exact_loc/len(d2['locations'])
                d2['in_conjunction_with_conceptual_average'] = total_conceptual_loc/len(d2['locations'])

            if k2 in in_conjunctions:
                in_conjunctions[k2]['in_conjunction_with_exact_avg_list'].append(d2['in_conjunction_with_exact_average'])
                in_conjunctions[k2]['in_conjunction_with_conceptual_avg_list'].append(d2['in_conjunction_with_conceptual_average'])
                in_conjunctions[k2]['in_conjunction_with_count'] += len(d2['locations'])
            else:
                in_conjunctions[k2] = {
                    'concept': k2,
                    'in_conjunction_with_exact_avg_list' :[d2['in_conjunction_with_exact_average']],
                    'in_conjunction_with_conceptual_avg_list' :[d2['in_conjunction_with_conceptual_average']],
                    'in_conjunction_with_count': len(d2['locations'])
                }

    # calculate the averages now that we have a list of positions
    for k2,d2 in in_conjunctions.items():
        #print("calc in_conjunctions: {} count:{}".format(k2,in_conjunctions[k2]['in_conjunction_with_count']))

        if 'in_conjunction_with_exact_avg_list' in d2:
            d2['in_conjunction_with_exact_avg_pos'] = statistics.mean(d2['in_conjunction_with_exact_avg_list'])
            # leave this value if you want the details on exact location
            d2.pop('in_conjunction_with_exact_avg_list')
        if 'in_conjunction_with_conceptual_avg_list' in d2:
            d2['in_conjunction_with_conceptual_avg_pos'] = statistics.mean(d2['in_conjunction_with_conceptual_avg_list'])
            # leave this value if you want the details on exact location
            d2.pop('in_conjunction_with_conceptual_avg_list')
    # we've done all the docs
    return in_conjunctions

# %% [markdown]
# ## Change the value "concept" to choose a different term then re-run from this next line

# %%
concept = "disappointed"

# %%
icw = in_conjunction_with_raw(related_docs[0:100], concept_term, related_term_ids, top_concepts_100)
icw
# Out:
# {'buy|en': {'concept': 'buy|en',
#   'in_conjunction_with_count': 95,
#   'in_conjunction_with_exact_avg_pos': 283.26100628930817,
#   'in_conjunction_with_conceptual_avg_pos': -3.2169811320754715},
#  'christmas|en': {'concept': 'christmas|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': 544.3214285714286,
#   'in_conjunction_with_conceptual_avg_pos': -173.21428571428572},
#  'nook|en': {'concept': 'nook|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': -160.02380952380952,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  'kindle|en fire|en hd|en': {'concept': 'kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 57,
#   'in_conjunction_with_exact_avg_pos': 590.3171717171717,
#   'in_conjunction_with_conceptual_avg_pos': 85.9060606060606},
#  'movie|en': {'concept': 'movie|en',
#   'in_conjunction_with_count': 33,
#   'in_conjunction_with_exact_avg_pos': 114.41176470588235,
#   'in_conjunction_with_conceptual_avg_pos': -113.83333333333333},
#  'book|en': {'concept': 'book|en',
#   'in_conjunction_with_count': 99,
#   'in_conjunction_with_exact_avg_pos': -47.441964285714285,
#   'in_conjunction_with_conceptual_avg_pos': -94.91785714285714},
#  'reader|en': {'concept': 'reader|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': -223.3,
#   'in_conjunction_with_conceptual_avg_pos': 187.1},
#  'web|en': {'concept': 'web|en',
#   'in_conjunction_with_count': 15,
#   'in_conjunction_with_exact_avg_pos': -190.04166666666666,
#   'in_conjunction_with_conceptual_avg_pos': -183.45833333333334},
#  'awesome|en': {'concept': 'awesome|en',
#   'in_conjunction_with_count': 6,
#   'in_conjunction_with_exact_avg_pos': -335.8,
#   'in_conjunction_with_conceptual_avg_pos': -119.4},
#  'amazon|en': {'concept': 'amazon|en',
#   'in_conjunction_with_count': 192,
#   'in_conjunction_with_exact_avg_pos': -111.5646505376344,
#   'in_conjunction_with_conceptual_avg_pos': -154.2068548387097},
#  'user|en': {'concept': 'user|en',
#   'in_conjunction_with_count': 18,
#   'in_conjunction_with_exact_avg_pos': -194.26190476190476,
#   'in_conjunction_with_conceptual_avg_pos': 230.21428571428572},
#  'kindle|en': {'concept': 'kindle|en',
#   'in_conjunction_with_count': 216,
#   'in_conjunction_with_exact_avg_pos': 33.48098438300052,
#   'in_conjunction_with_conceptual_avg_pos': -36.27222222222222},
#  'love|en kindle|en': {'concept': 'love|en kindle|en',
#   'in_conjunction_with_count': 2,
#   'in_conjunction_with_exact_avg_pos': 211.5,
#   'in_conjunction_with_conceptual_avg_pos': -497.0},
#  'computer|en': {'concept': 'computer|en',
#   'in_conjunction_with_count': 24,
#   'in_conjunction_with_exact_avg_pos': 65.16666666666667,
#   'in_conjunction_with_conceptual_avg_pos': 21.72222222222222},
#  'enjoy|en': {'concept': 'enjoy|en',
#   'in_conjunction_with_count': 14,
#   'in_conjunction_with_exact_avg_pos': 220.43333333333334,
#   'in_conjunction_with_conceptual_avg_pos': 123.0},
#  'read|en book|en': {'concept': 'read|en book|en',
#   'in_conjunction_with_count': 20,
#   'in_conjunction_with_exact_avg_pos': -174.7,
#   'in_conjunction_with_conceptual_avg_pos': -339.0},
#  'easy|en': {'concept': 'easy|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': -288.03921568627453,
#   'in_conjunction_with_conceptual_avg_pos': -60.588235294117645},
#  'read|en': {'concept': 'read|en',
#   'in_conjunction_with_count': 86,
#   'in_conjunction_with_exact_avg_pos': -2.293981481481478,
#   'in_conjunction_with_conceptual_avg_pos': -225.2101851851852},
#  'item|en': {'concept': 'item|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': 288.3177083333333,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  'highly|en recommend|en': {'concept': 'highly|en recommend|en',
#   'in_conjunction_with_count': 4,
#   'in_conjunction_with_exact_avg_pos': -303.75,
#   'in_conjunction_with_conceptual_avg_pos': 73.0},
#  'apple|en': {'concept': 'apple|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': -110.90625,
#   'in_conjunction_with_conceptual_avg_pos': 43.31875},
#  'feature|en': {'concept': 'feature|en',
#   'in_conjunction_with_count': 26,
#   'in_conjunction_with_exact_avg_pos': 124.7280701754386,
#   'in_conjunction_with_conceptual_avg_pos': 215.94736842105263},
#  'load|en': {'concept': 'load|en',
#   'in_conjunction_with_count': 20,
#   'in_conjunction_with_exact_avg_pos': 12.7051282051282,
#   'in_conjunction_with_conceptual_avg_pos': -126.76923076923077},
#  'app|en': {'concept': 'app|en',
#   'in_conjunction_with_count': 201,
#   'in_conjunction_with_exact_avg_pos': -0.5864416833166862,
#   'in_conjunction_with_conceptual_avg_pos': -113.66886446886447},
#  'download|en': {'concept': 'download|en',
#   'in_conjunction_with_count': 49,
#   'in_conjunction_with_exact_avg_pos': 29.84107142857143,
#   'in_conjunction_with_conceptual_avg_pos': -173.65},
#  'wifi|en': {'concept': 'wifi|en',
#   'in_conjunction_with_count': 16,
#   'in_conjunction_with_exact_avg_pos': 114.38461538461539,
#   'in_conjunction_with_conceptual_avg_pos': -109.76923076923077},
#  'stream|en': {'concept': 'stream|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': -363.3333333333333,
#   'in_conjunction_with_conceptual_avg_pos': -767.1111111111111},
#  'product|en': {'concept': 'product|en',
#   'in_conjunction_with_count': 34,
#   'in_conjunction_with_exact_avg_pos': -165.41666666666666,
#   'in_conjunction_with_conceptual_avg_pos': -171.62962962962962},
#  'price|en': {'concept': 'price|en',
#   'in_conjunction_with_count': 25,
#   'in_conjunction_with_exact_avg_pos': -313.0,
#   'in_conjunction_with_conceptual_avg_pos': 123.93181818181819},
#  'hd|en': {'concept': 'hd|en',
#   'in_conjunction_with_count': 50,
#   'in_conjunction_with_exact_avg_pos': -182.4502688172043,
#   'in_conjunction_with_conceptual_avg_pos': -305.3333333333333},
#  'customer|en': {'concept': 'customer|en',
#   'in_conjunction_with_count': 28,
#   'in_conjunction_with_exact_avg_pos': -155.9,
#   'in_conjunction_with_conceptual_avg_pos': 38.083333333333336},
#  'email|en': {'concept': 'email|en',
#   'in_conjunction_with_count': 14,
#   'in_conjunction_with_exact_avg_pos': 270.2395833333333,
#   'in_conjunction_with_conceptual_avg_pos': 463.375},
#  'device|en': {'concept': 'device|en',
#   'in_conjunction_with_count': 154,
#   'in_conjunction_with_exact_avg_pos': 63.500579975579974,
#   'in_conjunction_with_conceptual_avg_pos': -56.78472222222223},
#  'review|en': {'concept': 'review|en',
#   'in_conjunction_with_count': 32,
#   'in_conjunction_with_exact_avg_pos': -164.76190476190476,
#   'in_conjunction_with_conceptual_avg_pos': -127.73809523809524},
#  'improvement|en': {'concept': 'improvement|en',
#   'in_conjunction_with_count': 6,
#   'in_conjunction_with_exact_avg_pos': 276.2,
#   'in_conjunction_with_conceptual_avg_pos': -116.4},
#  'graphics|en': {'concept': 'graphics|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': -279.0,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  'audio|en': {'concept': 'audio|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': 158.0,
#   'in_conjunction_with_conceptual_avg_pos': 238.9375},
#  'screen|en': {'concept': 'screen|en',
#   'in_conjunction_with_count': 90,
#   'in_conjunction_with_exact_avg_pos': 150.6050925925926,
#   'in_conjunction_with_conceptual_avg_pos': 17.601190476190474},
#  'ship|en': {'concept': 'ship|en',
#   'in_conjunction_with_count': 18,
#   'in_conjunction_with_exact_avg_pos': -357.90909090909093,
#   'in_conjunction_with_conceptual_avg_pos': -39.63636363636363},
#  'new|en kindle|en': {'concept': 'new|en kindle|en',
#   'in_conjunction_with_count': 7,
#   'in_conjunction_with_exact_avg_pos': 62.0,
#   'in_conjunction_with_conceptual_avg_pos': -63.285714285714285},
#  'compare|en': {'concept': 'compare|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': 315.0,
#   'in_conjunction_with_conceptual_avg_pos': 684.7272727272727},
#  'customer|en service|en': {'concept': 'customer|en service|en',
#   'in_conjunction_with_count': 26,
#   'in_conjunction_with_exact_avg_pos': -222.9777777777778,
#   'in_conjunction_with_conceptual_avg_pos': -70.95555555555556},
#  'purchase|en': {'concept': 'purchase|en',
#   'in_conjunction_with_count': 70,
#   'in_conjunction_with_exact_avg_pos': 276.14529914529913,
#   'in_conjunction_with_conceptual_avg_pos': 48.88461538461539},
#  'kindle|en fire|en': {'concept': 'kindle|en fire|en',
#   'in_conjunction_with_count': 82,
#   'in_conjunction_with_exact_avg_pos': 298.04393424036283,
#   'in_conjunction_with_conceptual_avg_pos': -65.26785714285714},
#  'camera|en': {'concept': 'camera|en',
#   'in_conjunction_with_count': 59,
#   'in_conjunction_with_exact_avg_pos': -131.25093984962407,
#   'in_conjunction_with_conceptual_avg_pos': 52.1203007518797},
#  'ad|en': {'concept': 'ad|en',
#   'in_conjunction_with_count': 45,
#   'in_conjunction_with_exact_avg_pos': 17.00526315789473,
#   'in_conjunction_with_conceptual_avg_pos': 367.36842105263156},
#  'carousel|en': {'concept': 'carousel|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': 883.4444444444445,
#   'in_conjunction_with_conceptual_avg_pos': -219.25925925925927},
#  'complaint|en': {'concept': 'complaint|en',
#   'in_conjunction_with_count': 13,
#   'in_conjunction_with_exact_avg_pos': 351.9809523809524,
#   'in_conjunction_with_conceptual_avg_pos': -8.285714285714286},
#  'sound|en': {'concept': 'sound|en',
#   'in_conjunction_with_count': 39,
#   'in_conjunction_with_exact_avg_pos': 26.899999999999995,
#   'in_conjunction_with_conceptual_avg_pos': 8.127777777777789},
#  'android|en': {'concept': 'android|en',
#   'in_conjunction_with_count': 38,
#   'in_conjunction_with_exact_avg_pos': -103.6,
#   'in_conjunction_with_conceptual_avg_pos': -154.41666666666666},
#  'browser|en': {'concept': 'browser|en',
#   'in_conjunction_with_count': 19,
#   'in_conjunction_with_exact_avg_pos': 167.45833333333334,
#   'in_conjunction_with_conceptual_avg_pos': -321.4166666666667},
#  'flash|en': {'concept': 'flash|en',
#   'in_conjunction_with_count': 18,
#   'in_conjunction_with_exact_avg_pos': -21.662499999999994,
#   'in_conjunction_with_conceptual_avg_pos': 422.0},
#  'skype|en': {'concept': 'skype|en',
#   'in_conjunction_with_count': 17,
#   'in_conjunction_with_exact_avg_pos': 293.22727272727275,
#   'in_conjunction_with_conceptual_avg_pos': 41.36363636363637},
#  'update|en': {'concept': 'update|en',
#   'in_conjunction_with_count': 43,
#   'in_conjunction_with_exact_avg_pos': 37.01403508771929,
#   'in_conjunction_with_conceptual_avg_pos': -297.07894736842104},
#  'charge|en': {'concept': 'charge|en',
#   'in_conjunction_with_count': 44,
#   'in_conjunction_with_exact_avg_pos': -169.71733333333336,
#   'in_conjunction_with_conceptual_avg_pos': -309.71333333333337},
#  'battery|en': {'concept': 'battery|en',
#   'in_conjunction_with_count': 24,
#   'in_conjunction_with_exact_avg_pos': -428.72222222222223,
#   'in_conjunction_with_conceptual_avg_pos': -716.5722222222222},
#  'kindle|en fire|en hd|en 7|en': {'concept': 'kindle|en fire|en hd|en 7|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': 297.72727272727275,
#   'in_conjunction_with_conceptual_avg_pos': 29.727272727272727},
#  'tablet|en': {'concept': 'tablet|en',
#   'in_conjunction_with_count': 112,
#   'in_conjunction_with_exact_avg_pos': 57.94833333333334,
#   'in_conjunction_with_conceptual_avg_pos': -55.23199404761905},
#  'cheap|en': {'concept': 'cheap|en',
#   'in_conjunction_with_count': 5,
#   'in_conjunction_with_exact_avg_pos': 83.8,
#   'in_conjunction_with_conceptual_avg_pos': 635.8},
#  'ipad|en mini|en': {'concept': 'ipad|en mini|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': 208.9375,
#   'in_conjunction_with_conceptual_avg_pos': -93.125},
#  'kindle|en hd|en': {'concept': 'kindle|en hd|en',
#   'in_conjunction_with_count': 22,
#   'in_conjunction_with_exact_avg_pos': -276.1084656084656,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  'charger|en': {'concept': 'charger|en',
#   'in_conjunction_with_count': 21,
#   'in_conjunction_with_exact_avg_pos': -758.2361111111111,
#   'in_conjunction_with_conceptual_avg_pos': -514.0277777777777},
#  'recommend|en': {'concept': 'recommend|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': -189.58333333333334,
#   'in_conjunction_with_conceptual_avg_pos': -442.0833333333333},
#  'nexus|en 7|en': {'concept': 'nexus|en 7|en',
#   'in_conjunction_with_count': 28,
#   'in_conjunction_with_exact_avg_pos': -237.5,
#   'in_conjunction_with_conceptual_avg_pos': 120.1},
#  'ipad|en': {'concept': 'ipad|en',
#   'in_conjunction_with_count': 60,
#   'in_conjunction_with_exact_avg_pos': 40.08917748917749,
#   'in_conjunction_with_conceptual_avg_pos': 231.16565656565658},
#  'upgrade|en': {'concept': 'upgrade|en',
#   'in_conjunction_with_count': 17,
#   'in_conjunction_with_exact_avg_pos': 190.51388888888889,
#   'in_conjunction_with_conceptual_avg_pos': -232.66666666666666},
#  'browse|en': {'concept': 'browse|en',
#   'in_conjunction_with_count': 8,
#   'in_conjunction_with_exact_avg_pos': -281.0,
#   'in_conjunction_with_conceptual_avg_pos': -249.5},
#  'advertise|en': {'concept': 'advertise|en',
#   'in_conjunction_with_count': 6,
#   'in_conjunction_with_exact_avg_pos': 476.6666666666667,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  'magazine|en': {'concept': 'magazine|en',
#   'in_conjunction_with_count': 7,
#   'in_conjunction_with_exact_avg_pos': 856.8,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  'original|en kindle|en fire|en': {'concept': 'original|en kindle|en fire|en',
#   'in_conjunction_with_count': 14,
#   'in_conjunction_with_exact_avg_pos': 333.2375,
#   'in_conjunction_with_conceptual_avg_pos': 449.5625},
#  'new|en kindle|en fire|en hd|en': {'concept': 'new|en kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 7,
#   'in_conjunction_with_exact_avg_pos': 1031.0,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  'pro|en': {'concept': 'pro|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': -395.77777777777777,
#   'in_conjunction_with_conceptual_avg_pos': 357.1111111111111},
#  'fast|en': {'concept': 'fast|en',
#   'in_conjunction_with_count': 32,
#   'in_conjunction_with_exact_avg_pos': 55.041666666666664,
#   'in_conjunction_with_conceptual_avg_pos': -291.2708333333333},
#  'laptop|en': {'concept': 'laptop|en',
#   'in_conjunction_with_count': 6,
#   'in_conjunction_with_exact_avg_pos': -803.3333333333334,
#   'in_conjunction_with_conceptual_avg_pos': -701.5},
#  'iphone|en': {'concept': 'iphone|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': 179.5,
#   'in_conjunction_with_conceptual_avg_pos': -51.5},
#  'keyboard|en': {'concept': 'keyboard|en',
#   'in_conjunction_with_count': 20,
#   'in_conjunction_with_exact_avg_pos': 43.1125,
#   'in_conjunction_with_conceptual_avg_pos': -156.5},
#  'option|en': {'concept': 'option|en',
#   'in_conjunction_with_count': 19,
#   'in_conjunction_with_exact_avg_pos': -301.46666666666664,
#   'in_conjunction_with_conceptual_avg_pos': -144.26666666666668},
#  'amazon|en prime|en': {'concept': 'amazon|en prime|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': 363.2,
#   'in_conjunction_with_conceptual_avg_pos': 412.4},
#  'gift|en': {'concept': 'gift|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': 90.0,
#   'in_conjunction_with_conceptual_avg_pos': -44.6875},
#  'con|en': {'concept': 'con|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': -627.7916666666666,
#   'in_conjunction_with_conceptual_avg_pos': 513.5},
#  'connect|en': {'concept': 'connect|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': 93.5,
#   'in_conjunction_with_conceptual_avg_pos': -136.7},
#  'wi-fi|en': {'concept': 'wi-fi|en',
#   'in_conjunction_with_count': 15,
#   'in_conjunction_with_exact_avg_pos': 74.83333333333333,
#   'in_conjunction_with_conceptual_avg_pos': -285.1111111111111},
#  'button|en': {'concept': 'button|en',
#   'in_conjunction_with_count': 27,
#   'in_conjunction_with_exact_avg_pos': -466.5122222222222,
#   'in_conjunction_with_conceptual_avg_pos': -274.17333333333335},
#  'fire|en hd|en': {'concept': 'fire|en hd|en',
#   'in_conjunction_with_count': 35,
#   'in_conjunction_with_exact_avg_pos': 110.26190476190476,
#   'in_conjunction_with_conceptual_avg_pos': 7.169642857142857},
#  'battery|en life|en': {'concept': 'battery|en life|en',
#   'in_conjunction_with_count': 14,
#   'in_conjunction_with_exact_avg_pos': 166.1,
#   'in_conjunction_with_conceptual_avg_pos': 32.2},
#  'display|en': {'concept': 'display|en',
#   'in_conjunction_with_count': 22,
#   'in_conjunction_with_exact_avg_pos': 179.25,
#   'in_conjunction_with_conceptual_avg_pos': 342.68055555555554},
#  'plug|en': {'concept': 'plug|en',
#   'in_conjunction_with_count': 16,
#   'in_conjunction_with_exact_avg_pos': -278.9166666666667,
#   'in_conjunction_with_conceptual_avg_pos': -1028.5166666666667},
#  'old|en kindle|en': {'concept': 'old|en kindle|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': 24.416666666666668,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  'annoy|en': {'concept': 'annoy|en',
#   'in_conjunction_with_count': 13,
#   'in_conjunction_with_exact_avg_pos': -105.1,
#   'in_conjunction_with_conceptual_avg_pos': -794.8},
#  'install|en': {'concept': 'install|en',
#   'in_conjunction_with_count': 19,
#   'in_conjunction_with_exact_avg_pos': 26.694444444444457,
#   'in_conjunction_with_conceptual_avg_pos': -627.25},
#  'speaker|en': {'concept': 'speaker|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': -347.0897435897436,
#   'in_conjunction_with_conceptual_avg_pos': -11.128205128205128},
#  'replace|en': {'concept': 'replace|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': 405.55555555555554,
#   'in_conjunction_with_conceptual_avg_pos': -677.4444444444445},
#  'cloud|en': {'concept': 'cloud|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': -198.42857142857142,
#   'in_conjunction_with_conceptual_avg_pos': -189.9047619047619},
#  'excellent|en': {'concept': 'excellent|en',
#   'in_conjunction_with_count': 2,
#   'in_conjunction_with_exact_avg_pos': 611.0,
#   'in_conjunction_with_conceptual_avg_pos': -222.5},
#  'color|en': {'concept': 'color|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': -185.4375,
#   'in_conjunction_with_conceptual_avg_pos': 72.25},
#  'watch|en movie|en': {'concept': 'watch|en movie|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': -65.28571428571429,
#   'in_conjunction_with_conceptual_avg_pos': -7.357142857142857},
#  'netflix|en': {'concept': 'netflix|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': -463.25,
#   'in_conjunction_with_conceptual_avg_pos': 131.08333333333334},
#  'love|en kindle|en fire|en hd|en': {'concept': 'love|en kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 1,
#   'in_conjunction_with_exact_avg_pos': 0.0,
#   'in_conjunction_with_conceptual_avg_pos': 3924.0}}

# %%
sorted_icw = sorted(icw.items(), key=lambda x:x[1]['in_conjunction_with_count'], reverse=True)
sorted_icw = [icw for k,icw in dict(sorted_icw).items()]

# %%
sorted_icw
# Out:
# [{'concept': 'kindle|en',
#   'in_conjunction_with_count': 216,
#   'in_conjunction_with_exact_avg_pos': 33.48098438300052,
#   'in_conjunction_with_conceptual_avg_pos': -36.27222222222222},
#  {'concept': 'app|en',
#   'in_conjunction_with_count': 201,
#   'in_conjunction_with_exact_avg_pos': -0.5864416833166862,
#   'in_conjunction_with_conceptual_avg_pos': -113.66886446886447},
#  {'concept': 'amazon|en',
#   'in_conjunction_with_count': 192,
#   'in_conjunction_with_exact_avg_pos': -111.5646505376344,
#   'in_conjunction_with_conceptual_avg_pos': -154.2068548387097},
#  {'concept': 'device|en',
#   'in_conjunction_with_count': 154,
#   'in_conjunction_with_exact_avg_pos': 63.500579975579974,
#   'in_conjunction_with_conceptual_avg_pos': -56.78472222222223},
#  {'concept': 'tablet|en',
#   'in_conjunction_with_count': 112,
#   'in_conjunction_with_exact_avg_pos': 57.94833333333334,
#   'in_conjunction_with_conceptual_avg_pos': -55.23199404761905},
#  {'concept': 'book|en',
#   'in_conjunction_with_count': 99,
#   'in_conjunction_with_exact_avg_pos': -47.441964285714285,
#   'in_conjunction_with_conceptual_avg_pos': -94.91785714285714},
#  {'concept': 'buy|en',
#   'in_conjunction_with_count': 95,
#   'in_conjunction_with_exact_avg_pos': 283.26100628930817,
#   'in_conjunction_with_conceptual_avg_pos': -3.2169811320754715},
#  {'concept': 'screen|en',
#   'in_conjunction_with_count': 90,
#   'in_conjunction_with_exact_avg_pos': 150.6050925925926,
#   'in_conjunction_with_conceptual_avg_pos': 17.601190476190474},
#  {'concept': 'read|en',
#   'in_conjunction_with_count': 86,
#   'in_conjunction_with_exact_avg_pos': -2.293981481481478,
#   'in_conjunction_with_conceptual_avg_pos': -225.2101851851852},
#  {'concept': 'kindle|en fire|en',
#   'in_conjunction_with_count': 82,
#   'in_conjunction_with_exact_avg_pos': 298.04393424036283,
#   'in_conjunction_with_conceptual_avg_pos': -65.26785714285714},
#  {'concept': 'purchase|en',
#   'in_conjunction_with_count': 70,
#   'in_conjunction_with_exact_avg_pos': 276.14529914529913,
#   'in_conjunction_with_conceptual_avg_pos': 48.88461538461539},
#  {'concept': 'ipad|en',
#   'in_conjunction_with_count': 60,
#   'in_conjunction_with_exact_avg_pos': 40.08917748917749,
#   'in_conjunction_with_conceptual_avg_pos': 231.16565656565658},
#  {'concept': 'camera|en',
#   'in_conjunction_with_count': 59,
#   'in_conjunction_with_exact_avg_pos': -131.25093984962407,
#   'in_conjunction_with_conceptual_avg_pos': 52.1203007518797},
#  {'concept': 'kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 57,
#   'in_conjunction_with_exact_avg_pos': 590.3171717171717,
#   'in_conjunction_with_conceptual_avg_pos': 85.9060606060606},
#  {'concept': 'hd|en',
#   'in_conjunction_with_count': 50,
#   'in_conjunction_with_exact_avg_pos': -182.4502688172043,
#   'in_conjunction_with_conceptual_avg_pos': -305.3333333333333},
#  {'concept': 'download|en',
#   'in_conjunction_with_count': 49,
#   'in_conjunction_with_exact_avg_pos': 29.84107142857143,
#   'in_conjunction_with_conceptual_avg_pos': -173.65},
#  {'concept': 'ad|en',
#   'in_conjunction_with_count': 45,
#   'in_conjunction_with_exact_avg_pos': 17.00526315789473,
#   'in_conjunction_with_conceptual_avg_pos': 367.36842105263156},
#  {'concept': 'charge|en',
#   'in_conjunction_with_count': 44,
#   'in_conjunction_with_exact_avg_pos': -169.71733333333336,
#   'in_conjunction_with_conceptual_avg_pos': -309.71333333333337},
#  {'concept': 'update|en',
#   'in_conjunction_with_count': 43,
#   'in_conjunction_with_exact_avg_pos': 37.01403508771929,
#   'in_conjunction_with_conceptual_avg_pos': -297.07894736842104},
#  {'concept': 'sound|en',
#   'in_conjunction_with_count': 39,
#   'in_conjunction_with_exact_avg_pos': 26.899999999999995,
#   'in_conjunction_with_conceptual_avg_pos': 8.127777777777789},
#  {'concept': 'android|en',
#   'in_conjunction_with_count': 38,
#   'in_conjunction_with_exact_avg_pos': -103.6,
#   'in_conjunction_with_conceptual_avg_pos': -154.41666666666666},
#  {'concept': 'fire|en hd|en',
#   'in_conjunction_with_count': 35,
#   'in_conjunction_with_exact_avg_pos': 110.26190476190476,
#   'in_conjunction_with_conceptual_avg_pos': 7.169642857142857},
#  {'concept': 'product|en',
#   'in_conjunction_with_count': 34,
#   'in_conjunction_with_exact_avg_pos': -165.41666666666666,
#   'in_conjunction_with_conceptual_avg_pos': -171.62962962962962},
#  {'concept': 'movie|en',
#   'in_conjunction_with_count': 33,
#   'in_conjunction_with_exact_avg_pos': 114.41176470588235,
#   'in_conjunction_with_conceptual_avg_pos': -113.83333333333333},
#  {'concept': 'review|en',
#   'in_conjunction_with_count': 32,
#   'in_conjunction_with_exact_avg_pos': -164.76190476190476,
#   'in_conjunction_with_conceptual_avg_pos': -127.73809523809524},
#  {'concept': 'fast|en',
#   'in_conjunction_with_count': 32,
#   'in_conjunction_with_exact_avg_pos': 55.041666666666664,
#   'in_conjunction_with_conceptual_avg_pos': -291.2708333333333},
#  {'concept': 'customer|en',
#   'in_conjunction_with_count': 28,
#   'in_conjunction_with_exact_avg_pos': -155.9,
#   'in_conjunction_with_conceptual_avg_pos': 38.083333333333336},
#  {'concept': 'nexus|en 7|en',
#   'in_conjunction_with_count': 28,
#   'in_conjunction_with_exact_avg_pos': -237.5,
#   'in_conjunction_with_conceptual_avg_pos': 120.1},
#  {'concept': 'button|en',
#   'in_conjunction_with_count': 27,
#   'in_conjunction_with_exact_avg_pos': -466.5122222222222,
#   'in_conjunction_with_conceptual_avg_pos': -274.17333333333335},
#  {'concept': 'feature|en',
#   'in_conjunction_with_count': 26,
#   'in_conjunction_with_exact_avg_pos': 124.7280701754386,
#   'in_conjunction_with_conceptual_avg_pos': 215.94736842105263},
#  {'concept': 'customer|en service|en',
#   'in_conjunction_with_count': 26,
#   'in_conjunction_with_exact_avg_pos': -222.9777777777778,
#   'in_conjunction_with_conceptual_avg_pos': -70.95555555555556},
#  {'concept': 'price|en',
#   'in_conjunction_with_count': 25,
#   'in_conjunction_with_exact_avg_pos': -313.0,
#   'in_conjunction_with_conceptual_avg_pos': 123.93181818181819},
#  {'concept': 'computer|en',
#   'in_conjunction_with_count': 24,
#   'in_conjunction_with_exact_avg_pos': 65.16666666666667,
#   'in_conjunction_with_conceptual_avg_pos': 21.72222222222222},
#  {'concept': 'battery|en',
#   'in_conjunction_with_count': 24,
#   'in_conjunction_with_exact_avg_pos': -428.72222222222223,
#   'in_conjunction_with_conceptual_avg_pos': -716.5722222222222},
#  {'concept': 'christmas|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': 544.3214285714286,
#   'in_conjunction_with_conceptual_avg_pos': -173.21428571428572},
#  {'concept': 'nook|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': -160.02380952380952,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  {'concept': 'easy|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': -288.03921568627453,
#   'in_conjunction_with_conceptual_avg_pos': -60.588235294117645},
#  {'concept': 'item|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': 288.3177083333333,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  {'concept': 'apple|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': -110.90625,
#   'in_conjunction_with_conceptual_avg_pos': 43.31875},
#  {'concept': 'speaker|en',
#   'in_conjunction_with_count': 23,
#   'in_conjunction_with_exact_avg_pos': -347.0897435897436,
#   'in_conjunction_with_conceptual_avg_pos': -11.128205128205128},
#  {'concept': 'kindle|en hd|en',
#   'in_conjunction_with_count': 22,
#   'in_conjunction_with_exact_avg_pos': -276.1084656084656,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  {'concept': 'display|en',
#   'in_conjunction_with_count': 22,
#   'in_conjunction_with_exact_avg_pos': 179.25,
#   'in_conjunction_with_conceptual_avg_pos': 342.68055555555554},
#  {'concept': 'charger|en',
#   'in_conjunction_with_count': 21,
#   'in_conjunction_with_exact_avg_pos': -758.2361111111111,
#   'in_conjunction_with_conceptual_avg_pos': -514.0277777777777},
#  {'concept': 'read|en book|en',
#   'in_conjunction_with_count': 20,
#   'in_conjunction_with_exact_avg_pos': -174.7,
#   'in_conjunction_with_conceptual_avg_pos': -339.0},
#  {'concept': 'load|en',
#   'in_conjunction_with_count': 20,
#   'in_conjunction_with_exact_avg_pos': 12.7051282051282,
#   'in_conjunction_with_conceptual_avg_pos': -126.76923076923077},
#  {'concept': 'keyboard|en',
#   'in_conjunction_with_count': 20,
#   'in_conjunction_with_exact_avg_pos': 43.1125,
#   'in_conjunction_with_conceptual_avg_pos': -156.5},
#  {'concept': 'browser|en',
#   'in_conjunction_with_count': 19,
#   'in_conjunction_with_exact_avg_pos': 167.45833333333334,
#   'in_conjunction_with_conceptual_avg_pos': -321.4166666666667},
#  {'concept': 'option|en',
#   'in_conjunction_with_count': 19,
#   'in_conjunction_with_exact_avg_pos': -301.46666666666664,
#   'in_conjunction_with_conceptual_avg_pos': -144.26666666666668},
#  {'concept': 'install|en',
#   'in_conjunction_with_count': 19,
#   'in_conjunction_with_exact_avg_pos': 26.694444444444457,
#   'in_conjunction_with_conceptual_avg_pos': -627.25},
#  {'concept': 'user|en',
#   'in_conjunction_with_count': 18,
#   'in_conjunction_with_exact_avg_pos': -194.26190476190476,
#   'in_conjunction_with_conceptual_avg_pos': 230.21428571428572},
#  {'concept': 'ship|en',
#   'in_conjunction_with_count': 18,
#   'in_conjunction_with_exact_avg_pos': -357.90909090909093,
#   'in_conjunction_with_conceptual_avg_pos': -39.63636363636363},
#  {'concept': 'flash|en',
#   'in_conjunction_with_count': 18,
#   'in_conjunction_with_exact_avg_pos': -21.662499999999994,
#   'in_conjunction_with_conceptual_avg_pos': 422.0},
#  {'concept': 'skype|en',
#   'in_conjunction_with_count': 17,
#   'in_conjunction_with_exact_avg_pos': 293.22727272727275,
#   'in_conjunction_with_conceptual_avg_pos': 41.36363636363637},
#  {'concept': 'upgrade|en',
#   'in_conjunction_with_count': 17,
#   'in_conjunction_with_exact_avg_pos': 190.51388888888889,
#   'in_conjunction_with_conceptual_avg_pos': -232.66666666666666},
#  {'concept': 'wifi|en',
#   'in_conjunction_with_count': 16,
#   'in_conjunction_with_exact_avg_pos': 114.38461538461539,
#   'in_conjunction_with_conceptual_avg_pos': -109.76923076923077},
#  {'concept': 'plug|en',
#   'in_conjunction_with_count': 16,
#   'in_conjunction_with_exact_avg_pos': -278.9166666666667,
#   'in_conjunction_with_conceptual_avg_pos': -1028.5166666666667},
#  {'concept': 'web|en',
#   'in_conjunction_with_count': 15,
#   'in_conjunction_with_exact_avg_pos': -190.04166666666666,
#   'in_conjunction_with_conceptual_avg_pos': -183.45833333333334},
#  {'concept': 'wi-fi|en',
#   'in_conjunction_with_count': 15,
#   'in_conjunction_with_exact_avg_pos': 74.83333333333333,
#   'in_conjunction_with_conceptual_avg_pos': -285.1111111111111},
#  {'concept': 'enjoy|en',
#   'in_conjunction_with_count': 14,
#   'in_conjunction_with_exact_avg_pos': 220.43333333333334,
#   'in_conjunction_with_conceptual_avg_pos': 123.0},
#  {'concept': 'email|en',
#   'in_conjunction_with_count': 14,
#   'in_conjunction_with_exact_avg_pos': 270.2395833333333,
#   'in_conjunction_with_conceptual_avg_pos': 463.375},
#  {'concept': 'original|en kindle|en fire|en',
#   'in_conjunction_with_count': 14,
#   'in_conjunction_with_exact_avg_pos': 333.2375,
#   'in_conjunction_with_conceptual_avg_pos': 449.5625},
#  {'concept': 'battery|en life|en',
#   'in_conjunction_with_count': 14,
#   'in_conjunction_with_exact_avg_pos': 166.1,
#   'in_conjunction_with_conceptual_avg_pos': 32.2},
#  {'concept': 'complaint|en',
#   'in_conjunction_with_count': 13,
#   'in_conjunction_with_exact_avg_pos': 351.9809523809524,
#   'in_conjunction_with_conceptual_avg_pos': -8.285714285714286},
#  {'concept': 'annoy|en',
#   'in_conjunction_with_count': 13,
#   'in_conjunction_with_exact_avg_pos': -105.1,
#   'in_conjunction_with_conceptual_avg_pos': -794.8},
#  {'concept': 'reader|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': -223.3,
#   'in_conjunction_with_conceptual_avg_pos': 187.1},
#  {'concept': 'audio|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': 158.0,
#   'in_conjunction_with_conceptual_avg_pos': 238.9375},
#  {'concept': 'compare|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': 315.0,
#   'in_conjunction_with_conceptual_avg_pos': 684.7272727272727},
#  {'concept': 'recommend|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': -189.58333333333334,
#   'in_conjunction_with_conceptual_avg_pos': -442.0833333333333},
#  {'concept': 'con|en',
#   'in_conjunction_with_count': 12,
#   'in_conjunction_with_exact_avg_pos': -627.7916666666666,
#   'in_conjunction_with_conceptual_avg_pos': 513.5},
#  {'concept': 'carousel|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': 883.4444444444445,
#   'in_conjunction_with_conceptual_avg_pos': -219.25925925925927},
#  {'concept': 'kindle|en fire|en hd|en 7|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': 297.72727272727275,
#   'in_conjunction_with_conceptual_avg_pos': 29.727272727272727},
#  {'concept': 'old|en kindle|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': 24.416666666666668,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  {'concept': 'replace|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': 405.55555555555554,
#   'in_conjunction_with_conceptual_avg_pos': -677.4444444444445},
#  {'concept': 'cloud|en',
#   'in_conjunction_with_count': 11,
#   'in_conjunction_with_exact_avg_pos': -198.42857142857142,
#   'in_conjunction_with_conceptual_avg_pos': -189.9047619047619},
#  {'concept': 'stream|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': -363.3333333333333,
#   'in_conjunction_with_conceptual_avg_pos': -767.1111111111111},
#  {'concept': 'ipad|en mini|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': 208.9375,
#   'in_conjunction_with_conceptual_avg_pos': -93.125},
#  {'concept': 'pro|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': -395.77777777777777,
#   'in_conjunction_with_conceptual_avg_pos': 357.1111111111111},
#  {'concept': 'amazon|en prime|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': 363.2,
#   'in_conjunction_with_conceptual_avg_pos': 412.4},
#  {'concept': 'gift|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': 90.0,
#   'in_conjunction_with_conceptual_avg_pos': -44.6875},
#  {'concept': 'connect|en',
#   'in_conjunction_with_count': 10,
#   'in_conjunction_with_exact_avg_pos': 93.5,
#   'in_conjunction_with_conceptual_avg_pos': -136.7},
#  {'concept': 'graphics|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': -279.0,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  {'concept': 'iphone|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': 179.5,
#   'in_conjunction_with_conceptual_avg_pos': -51.5},
#  {'concept': 'color|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': -185.4375,
#   'in_conjunction_with_conceptual_avg_pos': 72.25},
#  {'concept': 'watch|en movie|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': -65.28571428571429,
#   'in_conjunction_with_conceptual_avg_pos': -7.357142857142857},
#  {'concept': 'netflix|en',
#   'in_conjunction_with_count': 9,
#   'in_conjunction_with_exact_avg_pos': -463.25,
#   'in_conjunction_with_conceptual_avg_pos': 131.08333333333334},
#  {'concept': 'browse|en',
#   'in_conjunction_with_count': 8,
#   'in_conjunction_with_exact_avg_pos': -281.0,
#   'in_conjunction_with_conceptual_avg_pos': -249.5},
#  {'concept': 'new|en kindle|en',
#   'in_conjunction_with_count': 7,
#   'in_conjunction_with_exact_avg_pos': 62.0,
#   'in_conjunction_with_conceptual_avg_pos': -63.285714285714285},
#  {'concept': 'magazine|en',
#   'in_conjunction_with_count': 7,
#   'in_conjunction_with_exact_avg_pos': 856.8,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  {'concept': 'new|en kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 7,
#   'in_conjunction_with_exact_avg_pos': 1031.0,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  {'concept': 'awesome|en',
#   'in_conjunction_with_count': 6,
#   'in_conjunction_with_exact_avg_pos': -335.8,
#   'in_conjunction_with_conceptual_avg_pos': -119.4},
#  {'concept': 'improvement|en',
#   'in_conjunction_with_count': 6,
#   'in_conjunction_with_exact_avg_pos': 276.2,
#   'in_conjunction_with_conceptual_avg_pos': -116.4},
#  {'concept': 'advertise|en',
#   'in_conjunction_with_count': 6,
#   'in_conjunction_with_exact_avg_pos': 476.6666666666667,
#   'in_conjunction_with_conceptual_avg_pos': 0.0},
#  {'concept': 'laptop|en',
#   'in_conjunction_with_count': 6,
#   'in_conjunction_with_exact_avg_pos': -803.3333333333334,
#   'in_conjunction_with_conceptual_avg_pos': -701.5},
#  {'concept': 'cheap|en',
#   'in_conjunction_with_count': 5,
#   'in_conjunction_with_exact_avg_pos': 83.8,
#   'in_conjunction_with_conceptual_avg_pos': 635.8},
#  {'concept': 'highly|en recommend|en',
#   'in_conjunction_with_count': 4,
#   'in_conjunction_with_exact_avg_pos': -303.75,
#   'in_conjunction_with_conceptual_avg_pos': 73.0},
#  {'concept': 'love|en kindle|en',
#   'in_conjunction_with_count': 2,
#   'in_conjunction_with_exact_avg_pos': 211.5,
#   'in_conjunction_with_conceptual_avg_pos': -497.0},
#  {'concept': 'excellent|en',
#   'in_conjunction_with_count': 2,
#   'in_conjunction_with_exact_avg_pos': 611.0,
#   'in_conjunction_with_conceptual_avg_pos': -222.5},
#  {'concept': 'love|en kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 1,
#   'in_conjunction_with_exact_avg_pos': 0.0,
#   'in_conjunction_with_conceptual_avg_pos': 3924.0}]

# %%
# write csv sample
# output the labeled results

# when you need a calculated list of fields
# fields = list(set(val for dic in result_data for val in dic.keys())) 
output_csv_file = "icw2_{}.csv".format(concept)
fields = sorted_icw[0].keys()
with open(output_csv_file, 'w') as f:
        writer = csv.DictWriter(f, fields)
        writer.writeheader()
        writer.writerows(sorted_icw)

# %% [markdown]
# # get in_conjunction data from the shared concept lists

# %%
# in_conjunction_with_raw
# Description: Find the concepts not directly associated with the concept_term_id
#              but in the same documents as concept_term_id and it's conceptual matches.
#              _raw takes raw concept lists
#
# Parameters:
#   docs: The documents to you want to measure
#   concept_term_id: The concept you are looking for conjunctions: disappoint|en
#   related_term_ids: The list of concept terms associated with concept_term_id 
#        ['disappoint|en',
#         'dissapointed|en',
#         'disappointment|en',
#         'etc']
def in_conjunction_with(concept, doc_filter = {}, top_concept_filter_count=-1):
    # get the details on this specific concept so we can get the term value
    cs = {"type": "specified", "concepts": [{"texts": [concept]}]}

    concept_details = client.get("/concepts", concept_selector=cs)["result"][0]
    # get the term value on the concept we are searching
    concept_term = concept_details['exact_term_ids'][0]

    # get the concepts related to the concept we are searching
    # this is so we know which concepts are not interesting
    cs = {"type": "related", "search_concept": {"texts": [concept]}, "limit": 50}
    related_concepts = client.get("/concepts", concept_selector=cs)["result"]

    # convert the list to a list of term_ids
    related_term_ids = [c['exact_term_ids'][0] for c in related_concepts]
    
    # get the documents for the concept
    related_docs = read_documents_by_concepts(client, [concept], filter=doc_filter)

    if top_concept_filter_count>0:
        cs = {"type": "top", "limit": top_concept_filter_count}
        top_concepts = client.get("/concepts", concept_selector=cs)["result"]
        top_concepts = [tc['exact_term_ids'][0] for tc in top_concepts]
    else:
        top_concepts = None
        
    icw = in_conjunction_with_raw(related_docs, concept_term, related_term_ids, top_concepts_100)
    sorted_icw = sorted(icw.items(), key=lambda x:x[1]['in_conjunction_with_count'], reverse=True)
    sorted_icw = [icw for k,icw in dict(sorted_icw).items()]
    
    return sorted_icw

# %%
concept_lists = client.get('concept_lists/')
concept_lists
# Out:
# [{'name': 'cluster7x4',
#   'concept_list_id': '70974115-be92-4249-9870-47591a158079',
#   'concepts': [{'shared_concept_id': 'edc90f25-9008-4244-82d8-fd3b72e1f461',
#     'name': 'download',
#     'texts': ['download'],
#     'color': '#808080'},
#    {'shared_concept_id': 'de9d7951-375c-4a4e-ac4e-1559468b7db2',
#     'name': 'Android',
#     'texts': ['Android'],
#     'color': '#808080'},
#    {'shared_concept_id': 'b49ceebc-8f7d-42e7-b49a-52f5e7400b92',
#     'name': 'email',
#     'texts': ['email'],
#     'color': '#808080'},
#    {'shared_concept_id': '3ebf081d-644c-49de-86b1-9a2da108e301',
#     'name': 'Skype',
#     'texts': ['Skype'],
#     'color': '#808080'},
#    {'shared_concept_id': '37461649-79fc-49b2-af8a-e96983fb59b4',
#     'name': 'iPad',
#     'texts': ['iPad'],
#     'color': '#808080'},
#    {'shared_concept_id': '4efa1e3d-53fe-497a-abf9-20f683065f06',
#     'name': 'device',
#     'texts': ['device'],
#     'color': '#808080'},
#    {'shared_concept_id': '2ebd8eee-8918-4ee2-987a-4fe2285e2f1a',
#     'name': 'charger',
#     'texts': ['charger'],
#     'color': '#808080'},
#    {'shared_concept_id': '9177c7ca-ba80-4314-b3a8-aa818c471271',
#     'name': 'laptop',
#     'texts': ['laptop'],
#     'color': '#808080'},
#    {'shared_concept_id': 'fe56f77c-3245-4682-86bb-4e3b81778b8f',
#     'name': 'screen',
#     'texts': ['screen'],
#     'color': '#808080'},
#    {'shared_concept_id': '95edd753-958e-4de8-8baf-47a681e4b705',
#     'name': 'display',
#     'texts': ['display'],
#     'color': '#808080'},
#    {'shared_concept_id': '3e50a60f-29b8-4ad1-af64-8f175a34f380',
#     'name': 'button',
#     'texts': ['button'],
#     'color': '#808080'},
#    {'shared_concept_id': 'e91877cf-8e2c-4271-a17d-52f7bbafbe03',
#     'name': 'features',
#     'texts': ['features'],
#     'color': '#808080'},
#    {'shared_concept_id': '37e8987a-1aca-4124-a829-c3ba2d6f1cdb',
#     'name': 'speakers',
#     'texts': ['speakers'],
#     'color': '#808080'},
#    {'shared_concept_id': '53de5a25-ade6-4f73-b2dc-948061e7c40e',
#     'name': 'Amazon Prime',
#     'texts': ['Amazon Prime'],
#     'color': '#808080'},
#    {'shared_concept_id': '9c46e4d2-e789-4f9e-8c5d-82a053967121',
#     'name': 'reader',
#     'texts': ['reader'],
#     'color': '#808080'},
#    {'shared_concept_id': '34cad88a-4e9a-413a-b863-f3a39d8ca9f6',
#     'name': 'movies',
#     'texts': ['movies'],
#     'color': '#808080'},
#    {'shared_concept_id': '6ee676b9-3b91-4bac-b459-01b66fee1168',
#     'name': 'Fire HD',
#     'texts': ['Fire HD'],
#     'color': '#808080'},
#    {'shared_concept_id': 'd4c200a9-b36b-4890-8358-1d8752e29174',
#     'name': 'Kindle Fire HD 7',
#     'texts': ['Kindle Fire HD 7'],
#     'color': '#808080'},
#    {'shared_concept_id': '31aa0e79-9612-48db-9f37-dbdcea82aaf6',
#     'name': 'upgrade',
#     'texts': ['upgrade'],
#     'color': '#808080'},
#    {'shared_concept_id': 'a4c16c66-7c04-479d-b86f-1ce7d585a798',
#     'name': 'gift',
#     'texts': ['gift'],
#     'color': '#808080'},
#    {'shared_concept_id': '8e3876bb-12e2-44d9-8307-e411ae80a621',
#     'name': 'recommend',
#     'texts': ['recommend'],
#     'color': '#808080'},
#    {'shared_concept_id': '718178d3-a2f0-4b0e-a858-4d9547d3851b',
#     'name': 'ads',
#     'texts': ['ads'],
#     'color': '#808080'},
#    {'shared_concept_id': '0a93b16c-b6bf-4696-96b9-395049b9b146',
#     'name': 'disappointed',
#     'texts': ['disappointed'],
#     'color': '#808080'},
#    {'shared_concept_id': 'f7015caf-3b0f-4923-b5b1-d3e6e7527854',
#     'name': 'item',
#     'texts': ['item'],
#     'color': '#808080'},
#    {'shared_concept_id': 'd91c5926-f4cf-41a7-9a4e-8c9a17ae6dcc',
#     'name': 'bought',
#     'texts': ['bought'],
#     'color': '#808080'},
#    {'shared_concept_id': 'e5d41970-a8d6-48a2-be58-f8ffddf06798',
#     'name': 'product',
#     'texts': ['product'],
#     'color': '#808080'},
#    {'shared_concept_id': '8e950b04-ee73-48dc-99f2-908520beae18',
#     'name': 'cheaper',
#     'texts': ['cheaper'],
#     'color': '#808080'},
#    {'shared_concept_id': '2e991404-9f4b-4717-b503-cb8adecc5074',
#     'name': 'shipping',
#     'texts': ['shipping'],
#     'color': '#808080'}]},
#  {'name': 'conjunction words',
#   'concept_list_id': 'f97bf5bc-dbb8-4a0f-871c-d172eb13cb30',
#   'concepts': [{'shared_concept_id': '8e1bf0ce-fb03-46f0-bd04-5f019064cee0',
#     'texts': ['bugs'],
#     'name': 'bugs',
#     'color': '#ff379c'},
#    {'shared_concept_id': 'f64175cc-ba4a-4999-88f1-28c733d4cf50',
#     'texts': ['error'],
#     'name': 'error',
#     'color': '#15cf20'},
#    {'shared_concept_id': 'f326ea8c-e0c9-4f12-b891-4ffd3aebf1d8',
#     'texts': ['hate'],
#     'name': 'hate',
#     'color': '#15cf20'},
#    {'shared_concept_id': '5df72aa9-e739-4cd5-850a-8935fc088cea',
#     'texts': ['Cons'],
#     'name': 'Cons',
#     'color': '#15cf20'},
#    {'shared_concept_id': '556bad9d-dec2-4fd1-9303-3a52afb24c6f',
#     'texts': ['Pros'],
#     'name': 'Pros',
#     'color': '#f07600'},
#    {'shared_concept_id': '830d8776-6475-470c-9b44-2a61d3423455',
#     'texts': ['complaint'],
#     'name': 'complaint',
#     'color': '#7d27bc'},
#    {'shared_concept_id': '45ce4be7-6f00-4202-94a9-8ecbfe1bd573',
#     'texts': ['complain'],
#     'name': 'complain',
#     'color': '#7d27bc'},
#    {'shared_concept_id': '59c91fc0-0120-4fd5-a530-cabeaf9f028f',
#     'texts': ['cost'],
#     'name': 'cost',
#     'color': '#ff0032'},
#    {'shared_concept_id': '561c96f7-1574-4891-8a87-babfe3eb0e48',
#     'texts': ['cheap'],
#     'name': 'cheap',
#     'color': '#00aaff'},
#    {'shared_concept_id': 'e79a0246-4805-4e0e-9556-f89f9ae7bccc',
#     'texts': ['expensive'],
#     'name': 'expensive',
#     'color': '#15cf20'},
#    {'shared_concept_id': '1641a351-c825-412a-9d3d-b011a43376eb',
#     'texts': ['wonderful'],
#     'name': 'wonderful',
#     'color': '#ffbb2a'},
#    {'shared_concept_id': '8f54dfc6-77a0-4f7e-bd03-3c5716caa367',
#     'texts': ['excellent'],
#     'name': 'excellent',
#     'color': '#aaaaaa'},
#    {'shared_concept_id': 'aeaa758c-d77d-47bd-94db-26164da0687e',
#     'texts': ['angry'],
#     'name': 'angry',
#     'color': '#7d27bc'},
#    {'shared_concept_id': '4e0a1ad9-b33b-43bf-9535-75c2ffd3d705',
#     'texts': ['surprised'],
#     'name': 'surprised',
#     'color': '#ff379c'},
#    {'shared_concept_id': 'de3b5634-ab06-4351-bf9b-5d29aba951d6',
#     'texts': ['annoying'],
#     'name': 'annoying',
#     'color': '#ff0032'},
#    {'shared_concept_id': '3856b66d-8c4e-4e19-8554-7f23f319f575',
#     'texts': ['love'],
#     'name': 'love',
#     'color': '#f07600'},
#    {'shared_concept_id': '2e5439e9-ec0b-425e-9c57-023f45bfaa3a',
#     'texts': ['excited'],
#     'name': 'excited',
#     'color': '#ffbb2a'},
#    {'shared_concept_id': '26370141-7687-4f8e-8494-6f4430a266d6',
#     'texts': ['happy'],
#     'name': 'happy',
#     'color': '#15cf20'},
#    {'shared_concept_id': 'f6607700-8441-481e-8027-bf73258a964d',
#     'texts': ['disappointment'],
#     'name': 'disappointment',
#     'color': '#00aaff'}]},
#  {'name': 'list from api',
#   'concept_list_id': '48bf41f1-a3a7-4f7b-8a8b-4483f0aba106',
#   'concepts': [{'shared_concept_id': '21a48e1b-eed3-4b74-89d2-2d1e761c1bb6',
#     'name': 'tablet',
#     'texts': ['tablet'],
#     'color': '#808080'},
#    {'shared_concept_id': 'a41fa5f9-cc93-4d33-9dee-7f647c2dfdc9',
#     'name': 'battery',
#     'texts': ['battery'],
#     'color': '#808080'}]},
#  {'name': 'MY LIST FROM API',
#   'concept_list_id': 'ad550058-0601-4eaa-bfd8-bb0d6ca4c427',
#   'concepts': [{'shared_concept_id': 'c7d55b72-233b-428b-8450-7f2fc96c421a',
#     'name': 'tablet',
#     'texts': ['tablet'],
#     'color': '#808080'},
#    {'shared_concept_id': '0a0e1cab-1c00-435c-832a-f394a02c647b',
#     'name': 'iPad',
#     'texts': ['iPad'],
#     'color': '#808080'}]},
#  {'name': 'Saved concepts (from API)',
#   'concept_list_id': 'saved',
#   'concepts': [{'shared_concept_id': 'ad352797-26cf-409d-8489-c2e5e30a2611',
#     'name': 'tablet',
#     'texts': ['tablet'],
#     'color': '#808080'},
#    {'shared_concept_id': 'ffe7d7c6-4b33-43dd-989d-c5c540802cf8',
#     'name': 'iPad',
#     'texts': ['iPad'],
#     'color': '#808080'},
#    {'shared_concept_id': '2714c4ac-1e18-47d0-a14f-27e1d325cb52',
#     'name': 'device',
#     'texts': ['device'],
#     'color': '#808080'},
#    {'shared_concept_id': 'a9c3012f-c9fd-4948-925a-37a89e3b4ed9',
#     'name': 'download',
#     'texts': ['download'],
#     'color': '#808080'},
#    {'shared_concept_id': 'caaae95c-ad43-4af9-9bd9-ccda7cead84b',
#     'name': 'HD',
#     'texts': ['HD'],
#     'color': '#808080'},
#    {'shared_concept_id': 'c8a35701-00f7-4ea7-9eac-777c7256d0da',
#     'name': 'screen',
#     'texts': ['screen'],
#     'color': '#808080'},
#    {'shared_concept_id': '34d46a11-ba45-4831-ac80-7f6f94af51ac',
#     'name': 'speakers',
#     'texts': ['speakers'],
#     'color': '#808080'},
#    {'shared_concept_id': 'bd787d08-eccb-403d-85ca-72cdb89f28ac',
#     'name': 'Amazon Prime',
#     'texts': ['Amazon Prime'],
#     'color': '#808080'},
#    {'shared_concept_id': 'cf99482c-368c-46b1-9e12-9d3f686d71e6',
#     'name': 'Kindle Fire',
#     'texts': ['Kindle Fire'],
#     'color': '#808080'},
#    {'shared_concept_id': 'f7d48189-a013-4ba0-82e2-08f6123f8408',
#     'name': 'Kindle Fire HD',
#     'texts': ['Kindle Fire HD'],
#     'color': '#808080'},
#    {'shared_concept_id': 'e7e8c8f0-dfba-4765-bf30-1dbfd86e079d',
#     'name': 'purchase',
#     'texts': ['purchase'],
#     'color': '#808080'},
#    {'shared_concept_id': '0d1ef5c1-bc70-46c4-86f4-9b8e8a506872',
#     'name': 'bought',
#     'texts': ['bought'],
#     'color': '#808080'}]},
#  {'name': 'sc3',
#   'concept_list_id': '97a9685b-0683-49ba-a608-58b3abb05d97',
#   'concepts': [{'shared_concept_id': 'e1a2e143-8bad-4461-ae65-797d4d212bc3',
#     'texts': ['screen'],
#     'name': 'screen',
#     'color': '#ffbb2a'},
#    {'shared_concept_id': 'eb88ce77-0980-4ad1-83f2-e1b54be7c370',
#     'texts': ['read'],
#     'name': 'read',
#     'color': '#15cf20'},
#    {'shared_concept_id': '4e96ad41-e798-491b-b519-7ead31d2fa01',
#     'texts': ['purchase'],
#     'name': 'purchase',
#     'color': '#00aaff'}]}]

# %%
# run a single concept as a test
in_conjunction_with(concept_lists[0]['concepts'][0]['name'], top_concept_filter_count=100)
# Out:
# [{'concept': 'kindle|en',
#   'in_conjunction_with_count': 1555,
#   'in_conjunction_with_exact_avg_pos': 55.622244135992126,
#   'in_conjunction_with_conceptual_avg_pos': -0.053832146437108055},
#  {'concept': 'app|en',
#   'in_conjunction_with_count': 1315,
#   'in_conjunction_with_exact_avg_pos': -3.5226120514596926,
#   'in_conjunction_with_conceptual_avg_pos': 1.0321242676312332},
#  {'concept': 'amazon|en',
#   'in_conjunction_with_count': 1279,
#   'in_conjunction_with_exact_avg_pos': -33.567281589755275,
#   'in_conjunction_with_conceptual_avg_pos': -40.517411185305924},
#  {'concept': 'device|en',
#   'in_conjunction_with_count': 1188,
#   'in_conjunction_with_exact_avg_pos': 51.2112221303337,
#   'in_conjunction_with_conceptual_avg_pos': 32.84839483289896},
#  {'concept': 'book|en',
#   'in_conjunction_with_count': 955,
#   'in_conjunction_with_exact_avg_pos': 11.182036578974044,
#   'in_conjunction_with_conceptual_avg_pos': 22.43177235385973},
#  {'concept': 'tablet|en',
#   'in_conjunction_with_count': 798,
#   'in_conjunction_with_exact_avg_pos': 130.91464732281207,
#   'in_conjunction_with_conceptual_avg_pos': -0.6834171608738074},
#  {'concept': 'buy|en',
#   'in_conjunction_with_count': 742,
#   'in_conjunction_with_exact_avg_pos': 28.935536599932487,
#   'in_conjunction_with_conceptual_avg_pos': 39.46401028277635},
#  {'concept': 'read|en',
#   'in_conjunction_with_count': 735,
#   'in_conjunction_with_exact_avg_pos': 86.11253273009648,
#   'in_conjunction_with_conceptual_avg_pos': 42.429378569180265},
#  {'concept': 'screen|en',
#   'in_conjunction_with_count': 594,
#   'in_conjunction_with_exact_avg_pos': 181.13959536820192,
#   'in_conjunction_with_conceptual_avg_pos': 85.88855581576892},
#  {'concept': 'kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 502,
#   'in_conjunction_with_exact_avg_pos': 185.4923143232132,
#   'in_conjunction_with_conceptual_avg_pos': 89.09036986733616},
#  {'concept': 'purchase|en',
#   'in_conjunction_with_count': 470,
#   'in_conjunction_with_exact_avg_pos': 69.18234567901234,
#   'in_conjunction_with_conceptual_avg_pos': 35.60166666666667},
#  {'concept': 'movie|en',
#   'in_conjunction_with_count': 434,
#   'in_conjunction_with_exact_avg_pos': 27.199197722567288,
#   'in_conjunction_with_conceptual_avg_pos': 31.161557971014492},
#  {'concept': 'kindle|en fire|en',
#   'in_conjunction_with_count': 411,
#   'in_conjunction_with_exact_avg_pos': 129.59560090702948,
#   'in_conjunction_with_conceptual_avg_pos': 75.52380952380952},
#  {'concept': 'ipad|en',
#   'in_conjunction_with_count': 408,
#   'in_conjunction_with_exact_avg_pos': 101.99919879062736,
#   'in_conjunction_with_conceptual_avg_pos': 17.144474678760396},
#  {'concept': 'easy|en',
#   'in_conjunction_with_count': 377,
#   'in_conjunction_with_exact_avg_pos': 49.500763612217796,
#   'in_conjunction_with_conceptual_avg_pos': 1.7739707835325387},
#  {'concept': 'fire|en hd|en',
#   'in_conjunction_with_count': 345,
#   'in_conjunction_with_exact_avg_pos': 310.3037580937581,
#   'in_conjunction_with_conceptual_avg_pos': 68.7187822671156},
#  {'concept': 'sound|en',
#   'in_conjunction_with_count': 334,
#   'in_conjunction_with_exact_avg_pos': 221.3157450076805,
#   'in_conjunction_with_conceptual_avg_pos': 76.0036866359447},
#  {'concept': 'hd|en',
#   'in_conjunction_with_count': 313,
#   'in_conjunction_with_exact_avg_pos': 125.62336159211159,
#   'in_conjunction_with_conceptual_avg_pos': 1.36689814814815},
#  {'concept': 'product|en',
#   'in_conjunction_with_count': 296,
#   'in_conjunction_with_exact_avg_pos': 22.778065630397236,
#   'in_conjunction_with_conceptual_avg_pos': -50.5339378238342},
#  {'concept': 'camera|en',
#   'in_conjunction_with_count': 283,
#   'in_conjunction_with_exact_avg_pos': -7.085862068965518,
#   'in_conjunction_with_conceptual_avg_pos': 23.922389162561576},
#  {'concept': 'feature|en',
#   'in_conjunction_with_count': 279,
#   'in_conjunction_with_exact_avg_pos': 45.97109943977591,
#   'in_conjunction_with_conceptual_avg_pos': -6.049019607843137},
#  {'concept': 'charge|en',
#   'in_conjunction_with_count': 278,
#   'in_conjunction_with_exact_avg_pos': -23.56230694980695,
#   'in_conjunction_with_conceptual_avg_pos': 11.448198198198197},
#  {'concept': 'price|en',
#   'in_conjunction_with_count': 257,
#   'in_conjunction_with_exact_avg_pos': -69.38183691308691,
#   'in_conjunction_with_conceptual_avg_pos': -13.850784632034632},
#  {'concept': 'fast|en',
#   'in_conjunction_with_count': 255,
#   'in_conjunction_with_exact_avg_pos': 128.26732209737827,
#   'in_conjunction_with_conceptual_avg_pos': 6.9719101123595495},
#  {'concept': 'update|en',
#   'in_conjunction_with_count': 232,
#   'in_conjunction_with_exact_avg_pos': -137.5299632352941,
#   'in_conjunction_with_conceptual_avg_pos': -9.143688725490197},
#  {'concept': 'review|en',
#   'in_conjunction_with_count': 230,
#   'in_conjunction_with_exact_avg_pos': 321.4390410958904,
#   'in_conjunction_with_conceptual_avg_pos': 77.8025114155251},
#  {'concept': 'ad|en',
#   'in_conjunction_with_count': 228,
#   'in_conjunction_with_exact_avg_pos': 21.35548433048433,
#   'in_conjunction_with_conceptual_avg_pos': -12.64031339031339},
#  {'concept': 'computer|en',
#   'in_conjunction_with_count': 219,
#   'in_conjunction_with_exact_avg_pos': 11.36364653243848,
#   'in_conjunction_with_conceptual_avg_pos': 69.65604026845637},
#  {'concept': 'android|en',
#   'in_conjunction_with_count': 217,
#   'in_conjunction_with_exact_avg_pos': 100.40000944822373,
#   'in_conjunction_with_conceptual_avg_pos': -27.034467120181407},
#  {'concept': 'speaker|en',
#   'in_conjunction_with_count': 206,
#   'in_conjunction_with_exact_avg_pos': 206.34142156862745,
#   'in_conjunction_with_conceptual_avg_pos': 78.03308823529412},
#  {'concept': 'install|en',
#   'in_conjunction_with_count': 203,
#   'in_conjunction_with_exact_avg_pos': 36.56780045351474,
#   'in_conjunction_with_conceptual_avg_pos': -9.004875283446712},
#  {'concept': 'wifi|en',
#   'in_conjunction_with_count': 200,
#   'in_conjunction_with_exact_avg_pos': 248.2181601731602,
#   'in_conjunction_with_conceptual_avg_pos': -65.0019696969697},
#  {'concept': 'cloud|en',
#   'in_conjunction_with_count': 197,
#   'in_conjunction_with_exact_avg_pos': 6.901229508196721,
#   'in_conjunction_with_conceptual_avg_pos': 52.64562841530055},
#  {'concept': 'display|en',
#   'in_conjunction_with_count': 185,
#   'in_conjunction_with_exact_avg_pos': 244.18033748033747,
#   'in_conjunction_with_conceptual_avg_pos': 113.14682539682539},
#  {'concept': 'button|en',
#   'in_conjunction_with_count': 182,
#   'in_conjunction_with_exact_avg_pos': 144.2436430883033,
#   'in_conjunction_with_conceptual_avg_pos': -106.76391585760518},
#  {'concept': 'email|en',
#   'in_conjunction_with_count': 178,
#   'in_conjunction_with_exact_avg_pos': -31.79530651340996,
#   'in_conjunction_with_conceptual_avg_pos': 42.35201149425287},
#  {'concept': 'charger|en',
#   'in_conjunction_with_count': 163,
#   'in_conjunction_with_exact_avg_pos': -96.9694572452637,
#   'in_conjunction_with_conceptual_avg_pos': -79.58486943164363},
#  {'concept': 'apple|en',
#   'in_conjunction_with_count': 160,
#   'in_conjunction_with_exact_avg_pos': 52.95510204081633,
#   'in_conjunction_with_conceptual_avg_pos': -114.46836734693878},
#  {'concept': 'read|en book|en',
#   'in_conjunction_with_count': 150,
#   'in_conjunction_with_exact_avg_pos': 185.00948509485096,
#   'in_conjunction_with_conceptual_avg_pos': 82.64227642276423},
#  {'concept': 'enjoy|en',
#   'in_conjunction_with_count': 139,
#   'in_conjunction_with_exact_avg_pos': 66.39583333333333,
#   'in_conjunction_with_conceptual_avg_pos': 51.84722222222222},
#  {'concept': 'reader|en',
#   'in_conjunction_with_count': 139,
#   'in_conjunction_with_exact_avg_pos': 89.79935515873017,
#   'in_conjunction_with_conceptual_avg_pos': 32.136160714285715},
#  {'concept': 'option|en',
#   'in_conjunction_with_count': 138,
#   'in_conjunction_with_exact_avg_pos': 0.1674836601307194,
#   'in_conjunction_with_conceptual_avg_pos': -5.676470588235294},
#  {'concept': 'watch|en movie|en',
#   'in_conjunction_with_count': 135,
#   'in_conjunction_with_exact_avg_pos': 41.62463126843658,
#   'in_conjunction_with_conceptual_avg_pos': 171.24778761061947},
#  {'concept': 'laptop|en',
#   'in_conjunction_with_count': 133,
#   'in_conjunction_with_exact_avg_pos': 142.9170068027211,
#   'in_conjunction_with_conceptual_avg_pos': -81.64795918367346},
#  {'concept': 'carousel|en',
#   'in_conjunction_with_count': 132,
#   'in_conjunction_with_exact_avg_pos': 56.19075342465753,
#   'in_conjunction_with_conceptual_avg_pos': 202.24109589041095},
#  {'concept': 'keyboard|en',
#   'in_conjunction_with_count': 131,
#   'in_conjunction_with_exact_avg_pos': 217.96831140350878,
#   'in_conjunction_with_conceptual_avg_pos': -11.048793859649122},
#  {'concept': 'kindle|en fire|en hd|en 7|en',
#   'in_conjunction_with_count': 130,
#   'in_conjunction_with_exact_avg_pos': 359.6267730496454,
#   'in_conjunction_with_conceptual_avg_pos': 287.47429078014187},
#  {'concept': 'nexus|en 7|en',
#   'in_conjunction_with_count': 126,
#   'in_conjunction_with_exact_avg_pos': 56.201010101010105,
#   'in_conjunction_with_conceptual_avg_pos': -184.2739898989899},
#  {'concept': 'plug|en',
#   'in_conjunction_with_count': 126,
#   'in_conjunction_with_exact_avg_pos': 99.09391891891892,
#   'in_conjunction_with_conceptual_avg_pos': -28.79954954954955},
#  {'concept': 'load|en',
#   'in_conjunction_with_count': 125,
#   'in_conjunction_with_exact_avg_pos': 9.658333333333335,
#   'in_conjunction_with_conceptual_avg_pos': 93.11481481481482},
#  {'concept': 'user|en',
#   'in_conjunction_with_count': 124,
#   'in_conjunction_with_exact_avg_pos': 188.52264492753622,
#   'in_conjunction_with_conceptual_avg_pos': -39.106884057971016},
#  {'concept': 'color|en',
#   'in_conjunction_with_count': 121,
#   'in_conjunction_with_exact_avg_pos': 187.53038194444446,
#   'in_conjunction_with_conceptual_avg_pos': 125.59635416666667},
#  {'concept': 'christmas|en',
#   'in_conjunction_with_count': 118,
#   'in_conjunction_with_exact_avg_pos': 208.24767025089605,
#   'in_conjunction_with_conceptual_avg_pos': 186.19534050179212},
#  {'concept': 'netflix|en',
#   'in_conjunction_with_count': 116,
#   'in_conjunction_with_exact_avg_pos': 50.43772893772894,
#   'in_conjunction_with_conceptual_avg_pos': 24.692307692307697},
#  {'concept': 'skype|en',
#   'in_conjunction_with_count': 116,
#   'in_conjunction_with_exact_avg_pos': 107.63505747126437,
#   'in_conjunction_with_conceptual_avg_pos': -55.26053639846743},
#  {'concept': 'web|en',
#   'in_conjunction_with_count': 116,
#   'in_conjunction_with_exact_avg_pos': 34.63703703703704,
#   'in_conjunction_with_conceptual_avg_pos': -39.544444444444444},
#  {'concept': 'connect|en',
#   'in_conjunction_with_count': 116,
#   'in_conjunction_with_exact_avg_pos': 82.45599758890899,
#   'in_conjunction_with_conceptual_avg_pos': 44.01898734177215},
#  {'concept': 'amazon|en prime|en',
#   'in_conjunction_with_count': 115,
#   'in_conjunction_with_exact_avg_pos': 149.15798611111111,
#   'in_conjunction_with_conceptual_avg_pos': 106.015625},
#  {'concept': 'compare|en',
#   'in_conjunction_with_count': 113,
#   'in_conjunction_with_exact_avg_pos': 433.7519379844961,
#   'in_conjunction_with_conceptual_avg_pos': 220.40891472868216},
#  {'concept': 'flash|en',
#   'in_conjunction_with_count': 111,
#   'in_conjunction_with_exact_avg_pos': 122.05078125,
#   'in_conjunction_with_conceptual_avg_pos': 184.14895833333333},
#  {'concept': 'stream|en',
#   'in_conjunction_with_count': 111,
#   'in_conjunction_with_exact_avg_pos': -16.51934156378601,
#   'in_conjunction_with_conceptual_avg_pos': -4.62962962962963},
#  {'concept': 'item|en',
#   'in_conjunction_with_count': 111,
#   'in_conjunction_with_exact_avg_pos': 95.23539886039886,
#   'in_conjunction_with_conceptual_avg_pos': 115.88034188034187},
#  {'concept': 'battery|en',
#   'in_conjunction_with_count': 109,
#   'in_conjunction_with_exact_avg_pos': -1.689546130952381,
#   'in_conjunction_with_conceptual_avg_pos': -32.40308779761905},
#  {'concept': 'customer|en',
#   'in_conjunction_with_count': 108,
#   'in_conjunction_with_exact_avg_pos': -190.73529411764707,
#   'in_conjunction_with_conceptual_avg_pos': -52.858823529411765},
#  {'concept': 'battery|en life|en',
#   'in_conjunction_with_count': 102,
#   'in_conjunction_with_exact_avg_pos': 7.823045267489712,
#   'in_conjunction_with_conceptual_avg_pos': 100.54526748971193},
#  {'concept': 'annoy|en',
#   'in_conjunction_with_count': 100,
#   'in_conjunction_with_exact_avg_pos': -137.10162601626016,
#   'in_conjunction_with_conceptual_avg_pos': -2.347560975609756},
#  {'concept': 'awesome|en',
#   'in_conjunction_with_count': 99,
#   'in_conjunction_with_exact_avg_pos': 9.761178861788618,
#   'in_conjunction_with_conceptual_avg_pos': 74.96951219512195},
#  {'concept': 'browser|en',
#   'in_conjunction_with_count': 98,
#   'in_conjunction_with_exact_avg_pos': 23.64251207729469,
#   'in_conjunction_with_conceptual_avg_pos': 41.81884057971015},
#  {'concept': 'kindle|en hd|en',
#   'in_conjunction_with_count': 96,
#   'in_conjunction_with_exact_avg_pos': 154.94119897959183,
#   'in_conjunction_with_conceptual_avg_pos': 15.014115646258503},
#  {'concept': 'pro|en',
#   'in_conjunction_with_count': 94,
#   'in_conjunction_with_exact_avg_pos': 285.0771144278607,
#   'in_conjunction_with_conceptual_avg_pos': 211.0},
#  {'concept': 'wi-fi|en',
#   'in_conjunction_with_count': 93,
#   'in_conjunction_with_exact_avg_pos': 46.855384615384615,
#   'in_conjunction_with_conceptual_avg_pos': 209.62307692307692},
#  {'concept': 'complaint|en',
#   'in_conjunction_with_count': 92,
#   'in_conjunction_with_exact_avg_pos': -29.769406392694062,
#   'in_conjunction_with_conceptual_avg_pos': -137.01552511415525},
#  {'concept': 'con|en',
#   'in_conjunction_with_count': 91,
#   'in_conjunction_with_exact_avg_pos': 102.17189054726369,
#   'in_conjunction_with_conceptual_avg_pos': 179.8689054726368},
#  {'concept': 'recommend|en',
#   'in_conjunction_with_count': 89,
#   'in_conjunction_with_exact_avg_pos': -364.88607594936707,
#   'in_conjunction_with_conceptual_avg_pos': -264.746835443038},
#  {'concept': 'ipad|en mini|en',
#   'in_conjunction_with_count': 88,
#   'in_conjunction_with_exact_avg_pos': 22.307909604519764,
#   'in_conjunction_with_conceptual_avg_pos': -20.666666666666668},
#  {'concept': 'nook|en',
#   'in_conjunction_with_count': 88,
#   'in_conjunction_with_exact_avg_pos': 54.88654761904762,
#   'in_conjunction_with_conceptual_avg_pos': 78.22416666666665},
#  {'concept': 'iphone|en',
#   'in_conjunction_with_count': 87,
#   'in_conjunction_with_exact_avg_pos': 165.77037933817596,
#   'in_conjunction_with_conceptual_avg_pos': 68.75649717514125},
#  {'concept': 'upgrade|en',
#   'in_conjunction_with_count': 84,
#   'in_conjunction_with_exact_avg_pos': 109.84741784037558,
#   'in_conjunction_with_conceptual_avg_pos': 51.460093896713616},
#  {'concept': 'excellent|en',
#   'in_conjunction_with_count': 80,
#   'in_conjunction_with_exact_avg_pos': 134.68686868686868,
#   'in_conjunction_with_conceptual_avg_pos': 119.63636363636364},
#  {'concept': 'gift|en',
#   'in_conjunction_with_count': 79,
#   'in_conjunction_with_exact_avg_pos': 200.5952380952381,
#   'in_conjunction_with_conceptual_avg_pos': 8.65},
#  {'concept': 'cheap|en',
#   'in_conjunction_with_count': 77,
#   'in_conjunction_with_exact_avg_pos': -90.48055555555555,
#   'in_conjunction_with_conceptual_avg_pos': 94.41111111111111},
#  {'concept': 'browse|en',
#   'in_conjunction_with_count': 74,
#   'in_conjunction_with_exact_avg_pos': -118.74415204678363,
#   'in_conjunction_with_conceptual_avg_pos': 19.907894736842106},
#  {'concept': 'magazine|en',
#   'in_conjunction_with_count': 74,
#   'in_conjunction_with_exact_avg_pos': 176.96978021978023,
#   'in_conjunction_with_conceptual_avg_pos': 97.9423076923077},
#  {'concept': 'ship|en',
#   'in_conjunction_with_count': 67,
#   'in_conjunction_with_exact_avg_pos': -128.59313725490196,
#   'in_conjunction_with_conceptual_avg_pos': 30.352941176470587},
#  {'concept': 'audio|en',
#   'in_conjunction_with_count': 64,
#   'in_conjunction_with_exact_avg_pos': 199.76,
#   'in_conjunction_with_conceptual_avg_pos': 79.07},
#  {'concept': 'customer|en service|en',
#   'in_conjunction_with_count': 64,
#   'in_conjunction_with_exact_avg_pos': -471.989837398374,
#   'in_conjunction_with_conceptual_avg_pos': -79.58536585365854},
#  {'concept': 'advertise|en',
#   'in_conjunction_with_count': 59,
#   'in_conjunction_with_exact_avg_pos': -136.0625,
#   'in_conjunction_with_conceptual_avg_pos': 131.32291666666666},
#  {'concept': 'improvement|en',
#   'in_conjunction_with_count': 54,
#   'in_conjunction_with_exact_avg_pos': 234.08288288288287,
#   'in_conjunction_with_conceptual_avg_pos': -74.29369369369368},
#  {'concept': 'original|en kindle|en fire|en',
#   'in_conjunction_with_count': 50,
#   'in_conjunction_with_exact_avg_pos': 1014.6,
#   'in_conjunction_with_conceptual_avg_pos': 185.61142857142858},
#  {'concept': 'new|en kindle|en',
#   'in_conjunction_with_count': 45,
#   'in_conjunction_with_exact_avg_pos': 39.16279069767442,
#   'in_conjunction_with_conceptual_avg_pos': -9.0},
#  {'concept': 'old|en kindle|en',
#   'in_conjunction_with_count': 42,
#   'in_conjunction_with_exact_avg_pos': 193.1451612903226,
#   'in_conjunction_with_conceptual_avg_pos': 80.0},
#  {'concept': 'replace|en',
#   'in_conjunction_with_count': 39,
#   'in_conjunction_with_exact_avg_pos': -84.86764705882354,
#   'in_conjunction_with_conceptual_avg_pos': -183.85294117647058},
#  {'concept': 'love|en kindle|en',
#   'in_conjunction_with_count': 36,
#   'in_conjunction_with_exact_avg_pos': 120.76470588235294,
#   'in_conjunction_with_conceptual_avg_pos': 32.8235294117647},
#  {'concept': 'highly|en recommend|en',
#   'in_conjunction_with_count': 34,
#   'in_conjunction_with_exact_avg_pos': -217.44117647058823,
#   'in_conjunction_with_conceptual_avg_pos': -55.3235294117647},
#  {'concept': 'new|en kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 32,
#   'in_conjunction_with_exact_avg_pos': 453.1049382716049,
#   'in_conjunction_with_conceptual_avg_pos': 567.1851851851852},
#  {'concept': 'love|en kindle|en fire|en hd|en',
#   'in_conjunction_with_count': 31,
#   'in_conjunction_with_exact_avg_pos': 381.58620689655174,
#   'in_conjunction_with_conceptual_avg_pos': 119.72413793103448},
#  {'concept': 'graphics|en',
#   'in_conjunction_with_count': 27,
#   'in_conjunction_with_exact_avg_pos': 33.2,
#   'in_conjunction_with_conceptual_avg_pos': 133.88}]

# %%
for cl in concept_lists:
    for c in cl['concepts']:
        c['in_conjunction_with'] = in_conjunction_with(c['name'], top_concept_filter_count=100)

# %%
concept_lists[0]
# Out:
# {'name': 'cluster7x4',
#  'concept_list_id': '70974115-be92-4249-9870-47591a158079',
#  'concepts': [{'shared_concept_id': 'edc90f25-9008-4244-82d8-fd3b72e1f461',
#    'name': 'download',
#    'texts': ['download'],
#    'color': '#808080',
#    'in_conjunction_with': [{'concept': 'kindle|en',
#      'in_conjunction_with_count': 1555,
#      'in_conjunction_with_exact_avg_pos': 55.622244135992126,
#      'in_conjunction_with_conceptual_avg_pos': -0.053832146437108055},
#     {'concept': 'app|en',
#      'in_conjunction_with_count': 1315,
#      'in_conjunction_with_exact_avg_pos': -3.5226120514596926,
#      'in_conjunction_with_conceptual_avg_pos': 1.0321242676312332},
#     {'concept': 'amazon|en',
#      'in_conjunction_with_count': 1279,
#      'in_conjunction_with_exact_avg_pos': -33.567281589755275,
#      'in_conjunction_with_conceptual_avg_pos': -40.517411185305924},
#     {'concept': 'device|en',
#      'in_conjunction_with_count': 1188,
#      'in_conjunction_with_exact_avg_pos': 51.2112221303337,
#      'in_conjunction_with_conceptual_avg_pos': 32.84839483289896},
#     {'concept': 'book|en',
#      'in_conjunction_with_count': 955,
#      'in_conjunction_with_exact_avg_pos': 11.182036578974044,
#      'in_conjunction_with_conceptual_avg_pos': 22.43177235385973},
#     {'concept': 'tablet|en',
#      'in_conjunction_with_count': 798,
#      'in_conjunction_with_exact_avg_pos': 130.91464732281207,
#      'in_conjunction_with_conceptual_avg_pos': -0.6834171608738074},
#     {'concept': 'buy|en',
#      'in_conjunction_with_count': 742,
#      'in_conjunction_with_exact_avg_pos': 28.935536599932487,
#      'in_conjunction_with_conceptual_avg_pos': 39.46401028277635},
#     {'concept': 'read|en',
#      'in_conjunction_with_count': 735,
#      'in_conjunction_with_exact_avg_pos': 86.11253273009648,
#      'in_conjunction_with_conceptual_avg_pos': 42.429378569180265},
#     {'concept': 'screen|en',
#      'in_conjunction_with_count': 594,
#      'in_conjunction_with_exact_avg_pos': 181.13959536820192,
#      'in_conjunction_with_conceptual_avg_pos': 85.88855581576892},
#     {'concept': 'kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 502,
#      'in_conjunction_with_exact_avg_pos': 185.4923143232132,
#      'in_conjunction_with_conceptual_avg_pos': 89.09036986733616},
#     {'concept': 'purchase|en',
#      'in_conjunction_with_count': 470,
#      'in_conjunction_with_exact_avg_pos': 69.18234567901234,
#      'in_conjunction_with_conceptual_avg_pos': 35.60166666666667},
#     {'concept': 'movie|en',
#      'in_conjunction_with_count': 434,
#      'in_conjunction_with_exact_avg_pos': 27.199197722567288,
#      'in_conjunction_with_conceptual_avg_pos': 31.161557971014492},
#     {'concept': 'kindle|en fire|en',
#      'in_conjunction_with_count': 411,
#      'in_conjunction_with_exact_avg_pos': 129.59560090702948,
#      'in_conjunction_with_conceptual_avg_pos': 75.52380952380952},
#     {'concept': 'ipad|en',
#      'in_conjunction_with_count': 408,
#      'in_conjunction_with_exact_avg_pos': 101.99919879062736,
#      'in_conjunction_with_conceptual_avg_pos': 17.144474678760396},
#     {'concept': 'easy|en',
#      'in_conjunction_with_count': 377,
#      'in_conjunction_with_exact_avg_pos': 49.500763612217796,
#      'in_conjunction_with_conceptual_avg_pos': 1.7739707835325387},
#     {'concept': 'fire|en hd|en',
#      'in_conjunction_with_count': 345,
#      'in_conjunction_with_exact_avg_pos': 310.3037580937581,
#      'in_conjunction_with_conceptual_avg_pos': 68.7187822671156},
#     {'concept': 'sound|en',
#      'in_conjunction_with_count': 334,
#      'in_conjunction_with_exact_avg_pos': 221.3157450076805,
#      'in_conjunction_with_conceptual_avg_pos': 76.0036866359447},
#     {'concept': 'hd|en',
#      'in_conjunction_with_count': 313,
#      'in_conjunction_with_exact_avg_pos': 125.62336159211159,
#      'in_conjunction_with_conceptual_avg_pos': 1.36689814814815},
#     {'concept': 'product|en',
#      'in_conjunction_with_count': 296,
#      'in_conjunction_with_exact_avg_pos': 22.778065630397236,
#      'in_conjunction_with_conceptual_avg_pos': -50.5339378238342},
#     {'concept': 'camera|en',
#      'in_conjunction_with_count': 283,
#      'in_conjunction_with_exact_avg_pos': -7.085862068965518,
#      'in_conjunction_with_conceptual_avg_pos': 23.922389162561576},
#     {'concept': 'feature|en',
#      'in_conjunction_with_count': 279,
#      'in_conjunction_with_exact_avg_pos': 45.97109943977591,
#      'in_conjunction_with_conceptual_avg_pos': -6.049019607843137},
#     {'concept': 'charge|en',
#      'in_conjunction_with_count': 278,
#      'in_conjunction_with_exact_avg_pos': -23.56230694980695,
#      'in_conjunction_with_conceptual_avg_pos': 11.448198198198197},
#     {'concept': 'price|en',
#      'in_conjunction_with_count': 257,
#      'in_conjunction_with_exact_avg_pos': -69.38183691308691,
#      'in_conjunction_with_conceptual_avg_pos': -13.850784632034632},
#     {'concept': 'fast|en',
#      'in_conjunction_with_count': 255,
#      'in_conjunction_with_exact_avg_pos': 128.26732209737827,
#      'in_conjunction_with_conceptual_avg_pos': 6.9719101123595495},
#     {'concept': 'update|en',
#      'in_conjunction_with_count': 232,
#      'in_conjunction_with_exact_avg_pos': -137.5299632352941,
#      'in_conjunction_with_conceptual_avg_pos': -9.143688725490197},
#     {'concept': 'review|en',
#      'in_conjunction_with_count': 230,
#      'in_conjunction_with_exact_avg_pos': 321.4390410958904,
#      'in_conjunction_with_conceptual_avg_pos': 77.8025114155251},
#     {'concept': 'ad|en',
#      'in_conjunction_with_count': 228,
#      'in_conjunction_with_exact_avg_pos': 21.35548433048433,
#      'in_conjunction_with_conceptual_avg_pos': -12.64031339031339},
#     {'concept': 'computer|en',
#      'in_conjunction_with_count': 219,
#      'in_conjunction_with_exact_avg_pos': 11.36364653243848,
#      'in_conjunction_with_conceptual_avg_pos': 69.65604026845637},
#     {'concept': 'android|en',
#      'in_conjunction_with_count': 217,
#      'in_conjunction_with_exact_avg_pos': 100.40000944822373,
#      'in_conjunction_with_conceptual_avg_pos': -27.034467120181407},
#     {'concept': 'speaker|en',
#      'in_conjunction_with_count': 206,
#      'in_conjunction_with_exact_avg_pos': 206.34142156862745,
#      'in_conjunction_with_conceptual_avg_pos': 78.03308823529412},
#     {'concept': 'install|en',
#      'in_conjunction_with_count': 203,
#      'in_conjunction_with_exact_avg_pos': 36.56780045351474,
#      'in_conjunction_with_conceptual_avg_pos': -9.004875283446712},
#     {'concept': 'wifi|en',
#      'in_conjunction_with_count': 200,
#      'in_conjunction_with_exact_avg_pos': 248.2181601731602,
#      'in_conjunction_with_conceptual_avg_pos': -65.0019696969697},
#     {'concept': 'cloud|en',
#      'in_conjunction_with_count': 197,
#      'in_conjunction_with_exact_avg_pos': 6.901229508196721,
#      'in_conjunction_with_conceptual_avg_pos': 52.64562841530055},
#     {'concept': 'display|en',
#      'in_conjunction_with_count': 185,
#      'in_conjunction_with_exact_avg_pos': 244.18033748033747,
#      'in_conjunction_with_conceptual_avg_pos': 113.14682539682539},
#     {'concept': 'button|en',
#      'in_conjunction_with_count': 182,
#      'in_conjunction_with_exact_avg_pos': 144.2436430883033,
#      'in_conjunction_with_conceptual_avg_pos': -106.76391585760518},
#     {'concept': 'email|en',
#      'in_conjunction_with_count': 178,
#      'in_conjunction_with_exact_avg_pos': -31.79530651340996,
#      'in_conjunction_with_conceptual_avg_pos': 42.35201149425287},
#     {'concept': 'charger|en',
#      'in_conjunction_with_count': 163,
#      'in_conjunction_with_exact_avg_pos': -96.9694572452637,
#      'in_conjunction_with_conceptual_avg_pos': -79.58486943164363},
#     {'concept': 'apple|en',
#      'in_conjunction_with_count': 160,
#      'in_conjunction_with_exact_avg_pos': 52.95510204081633,
#      'in_conjunction_with_conceptual_avg_pos': -114.46836734693878},
#     {'concept': 'read|en book|en',
#      'in_conjunction_with_count': 150,
#      'in_conjunction_with_exact_avg_pos': 185.00948509485096,
#      'in_conjunction_with_conceptual_avg_pos': 82.64227642276423},
#     {'concept': 'enjoy|en',
#      'in_conjunction_with_count': 139,
#      'in_conjunction_with_exact_avg_pos': 66.39583333333333,
#      'in_conjunction_with_conceptual_avg_pos': 51.84722222222222},
#     {'concept': 'reader|en',
#      'in_conjunction_with_count': 139,
#      'in_conjunction_with_exact_avg_pos': 89.79935515873017,
#      'in_conjunction_with_conceptual_avg_pos': 32.136160714285715},
#     {'concept': 'option|en',
#      'in_conjunction_with_count': 138,
#      'in_conjunction_with_exact_avg_pos': 0.1674836601307194,
#      'in_conjunction_with_conceptual_avg_pos': -5.676470588235294},
#     {'concept': 'watch|en movie|en',
#      'in_conjunction_with_count': 135,
#      'in_conjunction_with_exact_avg_pos': 41.62463126843658,
#      'in_conjunction_with_conceptual_avg_pos': 171.24778761061947},
#     {'concept': 'laptop|en',
#      'in_conjunction_with_count': 133,
#      'in_conjunction_with_exact_avg_pos': 142.9170068027211,
#      'in_conjunction_with_conceptual_avg_pos': -81.64795918367346},
#     {'concept': 'carousel|en',
#      'in_conjunction_with_count': 132,
#      'in_conjunction_with_exact_avg_pos': 56.19075342465753,
#      'in_conjunction_with_conceptual_avg_pos': 202.24109589041095},
#     {'concept': 'keyboard|en',
#      'in_conjunction_with_count': 131,
#      'in_conjunction_with_exact_avg_pos': 217.96831140350878,
#      'in_conjunction_with_conceptual_avg_pos': -11.048793859649122},
#     {'concept': 'kindle|en fire|en hd|en 7|en',
#      'in_conjunction_with_count': 130,
#      'in_conjunction_with_exact_avg_pos': 359.6267730496454,
#      'in_conjunction_with_conceptual_avg_pos': 287.47429078014187},
#     {'concept': 'nexus|en 7|en',
#      'in_conjunction_with_count': 126,
#      'in_conjunction_with_exact_avg_pos': 56.201010101010105,
#      'in_conjunction_with_conceptual_avg_pos': -184.2739898989899},
#     {'concept': 'plug|en',
#      'in_conjunction_with_count': 126,
#      'in_conjunction_with_exact_avg_pos': 99.09391891891892,
#      'in_conjunction_with_conceptual_avg_pos': -28.79954954954955},
#     {'concept': 'load|en',
#      'in_conjunction_with_count': 125,
#      'in_conjunction_with_exact_avg_pos': 9.658333333333335,
#      'in_conjunction_with_conceptual_avg_pos': 93.11481481481482},
#     {'concept': 'user|en',
#      'in_conjunction_with_count': 124,
#      'in_conjunction_with_exact_avg_pos': 188.52264492753622,
#      'in_conjunction_with_conceptual_avg_pos': -39.106884057971016},
#     {'concept': 'color|en',
#      'in_conjunction_with_count': 121,
#      'in_conjunction_with_exact_avg_pos': 187.53038194444446,
#      'in_conjunction_with_conceptual_avg_pos': 125.59635416666667},
#     {'concept': 'christmas|en',
#      'in_conjunction_with_count': 118,
#      'in_conjunction_with_exact_avg_pos': 208.24767025089605,
#      'in_conjunction_with_conceptual_avg_pos': 186.19534050179212},
#     {'concept': 'netflix|en',
#      'in_conjunction_with_count': 116,
#      'in_conjunction_with_exact_avg_pos': 50.43772893772894,
#      'in_conjunction_with_conceptual_avg_pos': 24.692307692307697},
#     {'concept': 'skype|en',
#      'in_conjunction_with_count': 116,
#      'in_conjunction_with_exact_avg_pos': 107.63505747126437,
#      'in_conjunction_with_conceptual_avg_pos': -55.26053639846743},
#     {'concept': 'web|en',
#      'in_conjunction_with_count': 116,
#      'in_conjunction_with_exact_avg_pos': 34.63703703703704,
#      'in_conjunction_with_conceptual_avg_pos': -39.544444444444444},
#     {'concept': 'connect|en',
#      'in_conjunction_with_count': 116,
#      'in_conjunction_with_exact_avg_pos': 82.45599758890899,
#      'in_conjunction_with_conceptual_avg_pos': 44.01898734177215},
#     {'concept': 'amazon|en prime|en',
#      'in_conjunction_with_count': 115,
#      'in_conjunction_with_exact_avg_pos': 149.15798611111111,
#      'in_conjunction_with_conceptual_avg_pos': 106.015625},
#     {'concept': 'compare|en',
#      'in_conjunction_with_count': 113,
#      'in_conjunction_with_exact_avg_pos': 433.7519379844961,
#      'in_conjunction_with_conceptual_avg_pos': 220.40891472868216},
#     {'concept': 'flash|en',
#      'in_conjunction_with_count': 111,
#      'in_conjunction_with_exact_avg_pos': 122.05078125,
#      'in_conjunction_with_conceptual_avg_pos': 184.14895833333333},
#     {'concept': 'stream|en',
#      'in_conjunction_with_count': 111,
#      'in_conjunction_with_exact_avg_pos': -16.51934156378601,
#      'in_conjunction_with_conceptual_avg_pos': -4.62962962962963},
#     {'concept': 'item|en',
#      'in_conjunction_with_count': 111,
#      'in_conjunction_with_exact_avg_pos': 95.23539886039886,
#      'in_conjunction_with_conceptual_avg_pos': 115.88034188034187},
#     {'concept': 'battery|en',
#      'in_conjunction_with_count': 109,
#      'in_conjunction_with_exact_avg_pos': -1.689546130952381,
#      'in_conjunction_with_conceptual_avg_pos': -32.40308779761905},
#     {'concept': 'customer|en',
#      'in_conjunction_with_count': 108,
#      'in_conjunction_with_exact_avg_pos': -190.73529411764707,
#      'in_conjunction_with_conceptual_avg_pos': -52.858823529411765},
#     {'concept': 'battery|en life|en',
#      'in_conjunction_with_count': 102,
#      'in_conjunction_with_exact_avg_pos': 7.823045267489712,
#      'in_conjunction_with_conceptual_avg_pos': 100.54526748971193},
#     {'concept': 'annoy|en',
#      'in_conjunction_with_count': 100,
#      'in_conjunction_with_exact_avg_pos': -137.10162601626016,
#      'in_conjunction_with_conceptual_avg_pos': -2.347560975609756},
#     {'concept': 'awesome|en',
#      'in_conjunction_with_count': 99,
#      'in_conjunction_with_exact_avg_pos': 9.761178861788618,
#      'in_conjunction_with_conceptual_avg_pos': 74.96951219512195},
#     {'concept': 'browser|en',
#      'in_conjunction_with_count': 98,
#      'in_conjunction_with_exact_avg_pos': 23.64251207729469,
#      'in_conjunction_with_conceptual_avg_pos': 41.81884057971015},
#     {'concept': 'kindle|en hd|en',
#      'in_conjunction_with_count': 96,
#      'in_conjunction_with_exact_avg_pos': 154.94119897959183,
#      'in_conjunction_with_conceptual_avg_pos': 15.014115646258503},
#     {'concept': 'pro|en',
#      'in_conjunction_with_count': 94,
#      'in_conjunction_with_exact_avg_pos': 285.0771144278607,
#      'in_conjunction_with_conceptual_avg_pos': 211.0},
#     {'concept': 'wi-fi|en',
#      'in_conjunction_with_count': 93,
#      'in_conjunction_with_exact_avg_pos': 46.855384615384615,
#      'in_conjunction_with_conceptual_avg_pos': 209.62307692307692},
#     {'concept': 'complaint|en',
#      'in_conjunction_with_count': 92,
#      'in_conjunction_with_exact_avg_pos': -29.769406392694062,
#      'in_conjunction_with_conceptual_avg_pos': -137.01552511415525},
#     {'concept': 'con|en',
#      'in_conjunction_with_count': 91,
#      'in_conjunction_with_exact_avg_pos': 102.17189054726369,
#      'in_conjunction_with_conceptual_avg_pos': 179.8689054726368},
#     {'concept': 'recommend|en',
#      'in_conjunction_with_count': 89,
#      'in_conjunction_with_exact_avg_pos': -364.88607594936707,
#      'in_conjunction_with_conceptual_avg_pos': -264.746835443038},
#     {'concept': 'ipad|en mini|en',
#      'in_conjunction_with_count': 88,
#      'in_conjunction_with_exact_avg_pos': 22.307909604519764,
#      'in_conjunction_with_conceptual_avg_pos': -20.666666666666668},
#     {'concept': 'nook|en',
#      'in_conjunction_with_count': 88,
#      'in_conjunction_with_exact_avg_pos': 54.88654761904762,
#      'in_conjunction_with_conceptual_avg_pos': 78.22416666666665},
#     {'concept': 'iphone|en',
#      'in_conjunction_with_count': 87,
#      'in_conjunction_with_exact_avg_pos': 165.77037933817596,
#      'in_conjunction_with_conceptual_avg_pos': 68.75649717514125},
#     {'concept': 'upgrade|en',
#      'in_conjunction_with_count': 84,
#      'in_conjunction_with_exact_avg_pos': 109.84741784037558,
#      'in_conjunction_with_conceptual_avg_pos': 51.460093896713616},
#     {'concept': 'excellent|en',
#      'in_conjunction_with_count': 80,
#      'in_conjunction_with_exact_avg_pos': 134.68686868686868,
#      'in_conjunction_with_conceptual_avg_pos': 119.63636363636364},
#     {'concept': 'gift|en',
#      'in_conjunction_with_count': 79,
#      'in_conjunction_with_exact_avg_pos': 200.5952380952381,
#      'in_conjunction_with_conceptual_avg_pos': 8.65},
#     {'concept': 'cheap|en',
#      'in_conjunction_with_count': 77,
#      'in_conjunction_with_exact_avg_pos': -90.48055555555555,
#      'in_conjunction_with_conceptual_avg_pos': 94.41111111111111},
#     {'concept': 'browse|en',
#      'in_conjunction_with_count': 74,
#      'in_conjunction_with_exact_avg_pos': -118.74415204678363,
#      'in_conjunction_with_conceptual_avg_pos': 19.907894736842106},
#     {'concept': 'magazine|en',
#      'in_conjunction_with_count': 74,
#      'in_conjunction_with_exact_avg_pos': 176.96978021978023,
#      'in_conjunction_with_conceptual_avg_pos': 97.9423076923077},
#     {'concept': 'ship|en',
#      'in_conjunction_with_count': 67,
#      'in_conjunction_with_exact_avg_pos': -128.59313725490196,
#      'in_conjunction_with_conceptual_avg_pos': 30.352941176470587},
#     {'concept': 'audio|en',
#      'in_conjunction_with_count': 64,
#      'in_conjunction_with_exact_avg_pos': 199.76,
#      'in_conjunction_with_conceptual_avg_pos': 79.07},
#     {'concept': 'customer|en service|en',
#      'in_conjunction_with_count': 64,
#      'in_conjunction_with_exact_avg_pos': -471.989837398374,
#      'in_conjunction_with_conceptual_avg_pos': -79.58536585365854},
#     {'concept': 'advertise|en',
#      'in_conjunction_with_count': 59,
#      'in_conjunction_with_exact_avg_pos': -136.0625,
#      'in_conjunction_with_conceptual_avg_pos': 131.32291666666666},
#     {'concept': 'improvement|en',
#      'in_conjunction_with_count': 54,
#      'in_conjunction_with_exact_avg_pos': 234.08288288288287,
#      'in_conjunction_with_conceptual_avg_pos': -74.29369369369368},
#     {'concept': 'original|en kindle|en fire|en',
#      'in_conjunction_with_count': 50,
#      'in_conjunction_with_exact_avg_pos': 1014.6,
#      'in_conjunction_with_conceptual_avg_pos': 185.61142857142858},
#     {'concept': 'new|en kindle|en',
#      'in_conjunction_with_count': 45,
#      'in_conjunction_with_exact_avg_pos': 39.16279069767442,
#      'in_conjunction_with_conceptual_avg_pos': -9.0},
#     {'concept': 'old|en kindle|en',
#      'in_conjunction_with_count': 42,
#      'in_conjunction_with_exact_avg_pos': 193.1451612903226,
#      'in_conjunction_with_conceptual_avg_pos': 80.0},
#     {'concept': 'replace|en',
#      'in_conjunction_with_count': 39,
#      'in_conjunction_with_exact_avg_pos': -84.86764705882354,
#      'in_conjunction_with_conceptual_avg_pos': -183.85294117647058},
#     {'concept': 'love|en kindle|en',
#      'in_conjunction_with_count': 36,
#      'in_conjunction_with_exact_avg_pos': 120.76470588235294,
#      'in_conjunction_with_conceptual_avg_pos': 32.8235294117647},
#     {'concept': 'highly|en recommend|en',
#      'in_conjunction_with_count': 34,
#      'in_conjunction_with_exact_avg_pos': -217.44117647058823,
#      'in_conjunction_with_conceptual_avg_pos': -55.3235294117647},
#     {'concept': 'new|en kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 32,
#      'in_conjunction_with_exact_avg_pos': 453.1049382716049,
#      'in_conjunction_with_conceptual_avg_pos': 567.1851851851852},
#     {'concept': 'love|en kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 31,
#      'in_conjunction_with_exact_avg_pos': 381.58620689655174,
#      'in_conjunction_with_conceptual_avg_pos': 119.72413793103448},
#     {'concept': 'graphics|en',
#      'in_conjunction_with_count': 27,
#      'in_conjunction_with_exact_avg_pos': 33.2,
#      'in_conjunction_with_conceptual_avg_pos': 133.88}]},
#   {'shared_concept_id': 'de9d7951-375c-4a4e-ac4e-1559468b7db2',
#    'name': 'Android',
#    'texts': ['Android'],
#    'color': '#808080',
#    'in_conjunction_with': [{'concept': 'app|en',
#      'in_conjunction_with_count': 1284,
#      'in_conjunction_with_exact_avg_pos': -0.007616278410941546,
#      'in_conjunction_with_conceptual_avg_pos': -19.585782548623754},
#     {'concept': 'amazon|en',
#      'in_conjunction_with_count': 1244,
#      'in_conjunction_with_exact_avg_pos': -9.888950989486704,
#      'in_conjunction_with_conceptual_avg_pos': -40.253710495853355},
#     {'concept': 'device|en',
#      'in_conjunction_with_count': 1222,
#      'in_conjunction_with_exact_avg_pos': 47.92211410919628,
#      'in_conjunction_with_conceptual_avg_pos': 21.95369595585473},
#     {'concept': 'kindle|en',
#      'in_conjunction_with_count': 1115,
#      'in_conjunction_with_exact_avg_pos': 76.96693704601189,
#      'in_conjunction_with_conceptual_avg_pos': 8.168110336165892},
#     {'concept': 'tablet|en',
#      'in_conjunction_with_count': 870,
#      'in_conjunction_with_exact_avg_pos': 57.52531552356324,
#      'in_conjunction_with_conceptual_avg_pos': -7.136939515883177},
#     {'concept': 'buy|en',
#      'in_conjunction_with_count': 621,
#      'in_conjunction_with_exact_avg_pos': 65.8060100325132,
#      'in_conjunction_with_conceptual_avg_pos': 30.696729957805907},
#     {'concept': 'screen|en',
#      'in_conjunction_with_count': 584,
#      'in_conjunction_with_exact_avg_pos': 196.27668934240364,
#      'in_conjunction_with_conceptual_avg_pos': 70.95649659863946},
#     {'concept': 'book|en',
#      'in_conjunction_with_count': 552,
#      'in_conjunction_with_exact_avg_pos': 96.89274844720497,
#      'in_conjunction_with_conceptual_avg_pos': 2.9037123745819393},
#     {'concept': 'read|en',
#      'in_conjunction_with_count': 509,
#      'in_conjunction_with_exact_avg_pos': 139.30117565698478,
#      'in_conjunction_with_conceptual_avg_pos': 52.15500559836659},
#     {'concept': 'ipad|en',
#      'in_conjunction_with_count': 492,
#      'in_conjunction_with_exact_avg_pos': 83.13450258018159,
#      'in_conjunction_with_conceptual_avg_pos': 20.14288683424486},
#     {'concept': 'kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 454,
#      'in_conjunction_with_exact_avg_pos': 250.53456750988803,
#      'in_conjunction_with_conceptual_avg_pos': 81.45877164146395},
#     {'concept': 'fire|en hd|en',
#      'in_conjunction_with_count': 349,
#      'in_conjunction_with_exact_avg_pos': 200.38721131114747,
#      'in_conjunction_with_conceptual_avg_pos': 63.376848269933376},
#     {'concept': 'purchase|en',
#      'in_conjunction_with_count': 346,
#      'in_conjunction_with_exact_avg_pos': 61.333907633405126,
#      'in_conjunction_with_conceptual_avg_pos': 43.43283082077052},
#     {'concept': 'kindle|en fire|en',
#      'in_conjunction_with_count': 340,
#      'in_conjunction_with_exact_avg_pos': 151.50535405872193,
#      'in_conjunction_with_conceptual_avg_pos': 65.29231433506045},
#     {'concept': 'movie|en',
#      'in_conjunction_with_count': 292,
#      'in_conjunction_with_exact_avg_pos': 71.31048387096774,
#      'in_conjunction_with_conceptual_avg_pos': 27.56505376344086},
#     {'concept': 'download|en',
#      'in_conjunction_with_count': 285,
#      'in_conjunction_with_exact_avg_pos': -26.164643545279382,
#      'in_conjunction_with_conceptual_avg_pos': 26.218497109826593},
#     {'concept': 'sound|en',
#      'in_conjunction_with_count': 274,
#      'in_conjunction_with_exact_avg_pos': 208.6125615763547,
#      'in_conjunction_with_conceptual_avg_pos': 89.8580459770115},
#     {'concept': 'price|en',
#      'in_conjunction_with_count': 269,
#      'in_conjunction_with_exact_avg_pos': -62.098502304147466,
#      'in_conjunction_with_conceptual_avg_pos': -19.06221198156682},
#     {'concept': 'hd|en',
#      'in_conjunction_with_count': 248,
#      'in_conjunction_with_exact_avg_pos': 105.75655555555555,
#      'in_conjunction_with_conceptual_avg_pos': -10.936388888888887},
#     {'concept': 'ad|en',
#      'in_conjunction_with_count': 239,
#      'in_conjunction_with_exact_avg_pos': -91.62994350282486,
#      'in_conjunction_with_conceptual_avg_pos': -57.18997175141243},
#     {'concept': 'apple|en',
#      'in_conjunction_with_count': 236,
#      'in_conjunction_with_exact_avg_pos': 94.6763888888889,
#      'in_conjunction_with_conceptual_avg_pos': -75.90208333333334},
#     {'concept': 'easy|en',
#      'in_conjunction_with_count': 232,
#      'in_conjunction_with_exact_avg_pos': 202.6521645021645,
#      'in_conjunction_with_conceptual_avg_pos': -13.527489177489175},
#     {'concept': 'speaker|en',
#      'in_conjunction_with_count': 220,
#      'in_conjunction_with_exact_avg_pos': 249.15571776155718,
#      'in_conjunction_with_conceptual_avg_pos': 59.21654501216545},
#     {'concept': 'iphone|en',
#      'in_conjunction_with_count': 216,
#      'in_conjunction_with_exact_avg_pos': 72.18303194695599,
#      'in_conjunction_with_conceptual_avg_pos': 34.83945147679325},
#     {'concept': 'charge|en',
#      'in_conjunction_with_count': 216,
#      'in_conjunction_with_exact_avg_pos': -21.11246105919003,
#      'in_conjunction_with_conceptual_avg_pos': -14.681464174454831},
#     {'concept': 'product|en',
#      'in_conjunction_with_count': 214,
#      'in_conjunction_with_exact_avg_pos': 20.868333333333332,
#      'in_conjunction_with_conceptual_avg_pos': -94.43333333333334},
#     {'concept': 'fast|en',
#      'in_conjunction_with_count': 206,
#      'in_conjunction_with_exact_avg_pos': 130.98090277777777,
#      'in_conjunction_with_conceptual_avg_pos': -19.899305555555557},
#     {'concept': 'review|en',
#      'in_conjunction_with_count': 204,
#      'in_conjunction_with_exact_avg_pos': 345.88666666666666,
#      'in_conjunction_with_conceptual_avg_pos': 129.516},
#     {'concept': 'nexus|en 7|en',
#      'in_conjunction_with_count': 196,
#      'in_conjunction_with_exact_avg_pos': 0.8708333333333309,
#      'in_conjunction_with_conceptual_avg_pos': -176.74083333333334},
#     {'concept': 'update|en',
#      'in_conjunction_with_count': 187,
#      'in_conjunction_with_exact_avg_pos': -102.96212121212122,
#      'in_conjunction_with_conceptual_avg_pos': -12.82159090909091},
#     {'concept': 'feature|en',
#      'in_conjunction_with_count': 181,
#      'in_conjunction_with_exact_avg_pos': 96.24984709480123,
#      'in_conjunction_with_conceptual_avg_pos': -10.743119266055047},
#     {'concept': 'display|en',
#      'in_conjunction_with_count': 178,
#      'in_conjunction_with_exact_avg_pos': 254.77657232704402,
#      'in_conjunction_with_conceptual_avg_pos': 72.91790206648697},
#     {'concept': 'camera|en',
#      'in_conjunction_with_count': 177,
#      'in_conjunction_with_exact_avg_pos': -78.06567944250871,
#      'in_conjunction_with_conceptual_avg_pos': 49.67007839721254},
#     {'concept': 'wifi|en',
#      'in_conjunction_with_count': 171,
#      'in_conjunction_with_exact_avg_pos': 207.12538046146292,
#      'in_conjunction_with_conceptual_avg_pos': -29.076975945017182},
#     {'concept': 'button|en',
#      'in_conjunction_with_count': 168,
#      'in_conjunction_with_exact_avg_pos': 112.8207702020202,
#      'in_conjunction_with_conceptual_avg_pos': -189.29810606060607},
#     {'concept': 'charger|en',
#      'in_conjunction_with_count': 157,
#      'in_conjunction_with_exact_avg_pos': -126.56341463414634,
#      'in_conjunction_with_conceptual_avg_pos': -98.45194541231126},
#     {'concept': 'user|en',
#      'in_conjunction_with_count': 148,
#      'in_conjunction_with_exact_avg_pos': 79.52954545454546,
#      'in_conjunction_with_conceptual_avg_pos': -79.17575757575757},
#     {'concept': 'carousel|en',
#      'in_conjunction_with_count': 145,
#      'in_conjunction_with_exact_avg_pos': 56.097093023255816,
#      'in_conjunction_with_conceptual_avg_pos': 154.12325581395348},
#     {'concept': 'computer|en',
#      'in_conjunction_with_count': 140,
#      'in_conjunction_with_exact_avg_pos': 0.8811881188118839,
#      'in_conjunction_with_conceptual_avg_pos': 120.78877887788778},
#     {'concept': 'compare|en',
#      'in_conjunction_with_count': 140,
#      'in_conjunction_with_exact_avg_pos': 95.47275641025641,
#      'in_conjunction_with_conceptual_avg_pos': 186.20352564102564},
#     {'concept': 'cloud|en',
#      'in_conjunction_with_count': 135,
#      'in_conjunction_with_exact_avg_pos': 27.516666666666666,
#      'in_conjunction_with_conceptual_avg_pos': 33.32286821705427},
#     {'concept': 'amazon|en prime|en',
#      'in_conjunction_with_count': 131,
#      'in_conjunction_with_exact_avg_pos': 47.38025889967638,
#      'in_conjunction_with_conceptual_avg_pos': -24.754045307443366},
#     {'concept': 'ipad|en mini|en',
#      'in_conjunction_with_count': 131,
#      'in_conjunction_with_exact_avg_pos': 166.38229166666667,
#      'in_conjunction_with_conceptual_avg_pos': 11.6875},
#     {'concept': 'email|en',
#      'in_conjunction_with_count': 130,
#      'in_conjunction_with_exact_avg_pos': -84.20392156862745,
#      'in_conjunction_with_conceptual_avg_pos': 26.570588235294117},
#     {'concept': 'option|en',
#      'in_conjunction_with_count': 126,
#      'in_conjunction_with_exact_avg_pos': -91.735,
#      'in_conjunction_with_conceptual_avg_pos': -60.585},
#     {'concept': 'netflix|en',
#      'in_conjunction_with_count': 119,
#      'in_conjunction_with_exact_avg_pos': 144.6621951219512,
#      'in_conjunction_with_conceptual_avg_pos': 13.158536585365857},
#     {'concept': 'read|en book|en',
#      'in_conjunction_with_count': 118,
#      'in_conjunction_with_exact_avg_pos': 180.10652920962198,
#      'in_conjunction_with_conceptual_avg_pos': 100.95360824742268},
#     {'concept': 'reader|en',
#      'in_conjunction_with_count': 117,
#      'in_conjunction_with_exact_avg_pos': 132.39301587301588,
#      'in_conjunction_with_conceptual_avg_pos': -26.385714285714286},
#     {'concept': 'stream|en',
#      'in_conjunction_with_count': 114,
#      'in_conjunction_with_exact_avg_pos': 145.3657894736842,
#      'in_conjunction_with_conceptual_avg_pos': 9.442982456140351},
#     {'concept': 'laptop|en',
#      'in_conjunction_with_count': 112,
#      'in_conjunction_with_exact_avg_pos': 282.30452674897117,
#      'in_conjunction_with_conceptual_avg_pos': -83.74074074074075},
#     {'concept': 'browser|en',
#      'in_conjunction_with_count': 108,
#      'in_conjunction_with_exact_avg_pos': 194.85037878787878,
#      'in_conjunction_with_conceptual_avg_pos': 38.265151515151516},
#     {'concept': 'load|en',
#      'in_conjunction_with_count': 107,
#      'in_conjunction_with_exact_avg_pos': 183.38693693693693,
#      'in_conjunction_with_conceptual_avg_pos': -1.274774774774776},
#     {'concept': 'keyboard|en',
#      'in_conjunction_with_count': 105,
#      'in_conjunction_with_exact_avg_pos': -81.20277777777778,
#      'in_conjunction_with_conceptual_avg_pos': 11.519444444444446},
#     {'concept': 'plug|en',
#      'in_conjunction_with_count': 102,
#      'in_conjunction_with_exact_avg_pos': -85.704802259887,
#      'in_conjunction_with_conceptual_avg_pos': -68.68361581920904},
#     {'concept': 'pro|en',
#      'in_conjunction_with_count': 100,
#      'in_conjunction_with_exact_avg_pos': 492.5779220779221,
#      'in_conjunction_with_conceptual_avg_pos': 228.2987012987013},
#     {'concept': 'customer|en',
#      'in_conjunction_with_count': 100,
#      'in_conjunction_with_exact_avg_pos': 4.829113924050633,
#      'in_conjunction_with_conceptual_avg_pos': -80.9535864978903},
#     {'concept': 'install|en',
#      'in_conjunction_with_count': 99,
#      'in_conjunction_with_exact_avg_pos': 132.2910447761194,
#      'in_conjunction_with_conceptual_avg_pos': 13.225124378109456},
#     {'concept': 'battery|en life|en',
#      'in_conjunction_with_count': 97,
#      'in_conjunction_with_exact_avg_pos': -69.62910798122066,
#      'in_conjunction_with_conceptual_avg_pos': 131.70657276995306},
#     {'concept': 'watch|en movie|en',
#      'in_conjunction_with_count': 96,
#      'in_conjunction_with_exact_avg_pos': 53.303030303030305,
#      'in_conjunction_with_conceptual_avg_pos': 129.8896103896104},
#     {'concept': 'web|en',
#      'in_conjunction_with_count': 94,
#      'in_conjunction_with_exact_avg_pos': 160.51898734177215,
#      'in_conjunction_with_conceptual_avg_pos': -72.56118143459915},
#     {'concept': 'annoy|en',
#      'in_conjunction_with_count': 92,
#      'in_conjunction_with_exact_avg_pos': -96.0680751173709,
#      'in_conjunction_with_conceptual_avg_pos': -71.4225352112676},
#     {'concept': 'con|en',
#      'in_conjunction_with_count': 90,
#      'in_conjunction_with_exact_avg_pos': 207.71517412935324,
#      'in_conjunction_with_conceptual_avg_pos': 241.85398009950248},
#     {'concept': 'skype|en',
#      'in_conjunction_with_count': 89,
#      'in_conjunction_with_exact_avg_pos': -8.092307692307692,
#      'in_conjunction_with_conceptual_avg_pos': -61.51025641025641},
#     {'concept': 'kindle|en fire|en hd|en 7|en',
#      'in_conjunction_with_count': 87,
#      'in_conjunction_with_exact_avg_pos': 427.08862433862436,
#      'in_conjunction_with_conceptual_avg_pos': 363.0529100529101},
#     {'concept': 'complaint|en',
#      'in_conjunction_with_count': 87,
#      'in_conjunction_with_exact_avg_pos': 72.06102564102564,
#      'in_conjunction_with_conceptual_avg_pos': -171.84820512820514},
#     {'concept': 'flash|en',
#      'in_conjunction_with_count': 86,
#      'in_conjunction_with_exact_avg_pos': 149.97592592592594,
#      'in_conjunction_with_conceptual_avg_pos': 233.8061728395062},
#     {'concept': 'color|en',
#      'in_conjunction_with_count': 84,
#      'in_conjunction_with_exact_avg_pos': 258.1119791666667,
#      'in_conjunction_with_conceptual_avg_pos': 215.37109375},
#     {'concept': 'connect|en',
#      'in_conjunction_with_count': 84,
#      'in_conjunction_with_exact_avg_pos': 180.20214285714286,
#      'in_conjunction_with_conceptual_avg_pos': 22.793333333333333},
#     {'concept': 'awesome|en',
#      'in_conjunction_with_count': 84,
#      'in_conjunction_with_exact_avg_pos': 50.67424242424242,
#      'in_conjunction_with_conceptual_avg_pos': 38.98232323232323},
#     {'concept': 'magazine|en',
#      'in_conjunction_with_count': 82,
#      'in_conjunction_with_exact_avg_pos': -24.09394409937888,
#      'in_conjunction_with_conceptual_avg_pos': 98.70434782608696},
#     {'concept': 'battery|en',
#      'in_conjunction_with_count': 82,
#      'in_conjunction_with_exact_avg_pos': 118.77173913043478,
#      'in_conjunction_with_conceptual_avg_pos': -39.43038302277433},
#     {'concept': 'upgrade|en',
#      'in_conjunction_with_count': 78,
#      'in_conjunction_with_exact_avg_pos': 174.30769230769232,
#      'in_conjunction_with_conceptual_avg_pos': 102.33333333333333},
#     {'concept': 'enjoy|en',
#      'in_conjunction_with_count': 78,
#      'in_conjunction_with_exact_avg_pos': 174.09166666666667,
#      'in_conjunction_with_conceptual_avg_pos': 8.125},
#     {'concept': 'item|en',
#      'in_conjunction_with_count': 76,
#      'in_conjunction_with_exact_avg_pos': -25.884848484848483,
#      'in_conjunction_with_conceptual_avg_pos': 101.36666666666666},
#     {'concept': 'browse|en',
#      'in_conjunction_with_count': 75,
#      'in_conjunction_with_exact_avg_pos': 9.057377049180328,
#      'in_conjunction_with_conceptual_avg_pos': -105.22540983606558},
#     {'concept': 'wi-fi|en',
#      'in_conjunction_with_count': 75,
#      'in_conjunction_with_exact_avg_pos': -75.08695652173913,
#      'in_conjunction_with_conceptual_avg_pos': 299.56159420289856},
#     {'concept': 'recommend|en',
#      'in_conjunction_with_count': 74,
#      'in_conjunction_with_exact_avg_pos': -194.68939393939394,
#      'in_conjunction_with_conceptual_avg_pos': -228.86363636363637},
#     {'concept': 'kindle|en hd|en',
#      'in_conjunction_with_count': 72,
#      'in_conjunction_with_exact_avg_pos': 275.0149442755826,
#      'in_conjunction_with_conceptual_avg_pos': 77.57497467071936},
#     {'concept': 'excellent|en',
#      'in_conjunction_with_count': 65,
#      'in_conjunction_with_exact_avg_pos': 318.9901960784314,
#      'in_conjunction_with_conceptual_avg_pos': 118.96078431372548},
#     {'concept': 'improvement|en',
#      'in_conjunction_with_count': 64,
#      'in_conjunction_with_exact_avg_pos': -45.25797101449275,
#      'in_conjunction_with_conceptual_avg_pos': -82.67101449275361},
#     {'concept': 'ship|en',
#      'in_conjunction_with_count': 64,
#      'in_conjunction_with_exact_avg_pos': 176.0965909090909,
#      'in_conjunction_with_conceptual_avg_pos': -19.261363636363637},
#     {'concept': 'advertise|en',
#      'in_conjunction_with_count': 62,
#      'in_conjunction_with_exact_avg_pos': -295.3888888888889,
#      'in_conjunction_with_conceptual_avg_pos': 51.177083333333336},
#     {'concept': 'audio|en',
#      'in_conjunction_with_count': 62,
#      'in_conjunction_with_exact_avg_pos': 135.1595744680851,
#      'in_conjunction_with_conceptual_avg_pos': 62.351063829787236},
#     {'concept': 'nook|en',
#      'in_conjunction_with_count': 60,
#      'in_conjunction_with_exact_avg_pos': 402.1702380952381,
#      'in_conjunction_with_conceptual_avg_pos': 136.39761904761903},
#     {'concept': 'christmas|en',
#      'in_conjunction_with_count': 57,
#      'in_conjunction_with_exact_avg_pos': 301.8643410852713,
#      'in_conjunction_with_conceptual_avg_pos': 390.29457364341084},
#     {'concept': 'cheap|en',
#      'in_conjunction_with_count': 51,
#      'in_conjunction_with_exact_avg_pos': -168.79761904761904,
#      'in_conjunction_with_conceptual_avg_pos': 62.968253968253975},
#     {'concept': 'original|en kindle|en fire|en',
#      'in_conjunction_with_count': 49,
#      'in_conjunction_with_exact_avg_pos': 514.3333333333334,
#      'in_conjunction_with_conceptual_avg_pos': 159.83333333333334},
#     {'concept': 'gift|en',
#      'in_conjunction_with_count': 41,
#      'in_conjunction_with_exact_avg_pos': -18.05982905982906,
#      'in_conjunction_with_conceptual_avg_pos': 6.666666666666667},
#     {'concept': 'replace|en',
#      'in_conjunction_with_count': 39,
#      'in_conjunction_with_exact_avg_pos': -69.52777777777777,
#      'in_conjunction_with_conceptual_avg_pos': -133.08333333333334},
#     {'concept': 'customer|en service|en',
#      'in_conjunction_with_count': 36,
#      'in_conjunction_with_exact_avg_pos': -243.46153846153845,
#      'in_conjunction_with_conceptual_avg_pos': -220.01282051282053},
#     {'concept': 'old|en kindle|en',
#      'in_conjunction_with_count': 27,
#      'in_conjunction_with_exact_avg_pos': 278.15909090909093,
#      'in_conjunction_with_conceptual_avg_pos': 213.5909090909091},
#     {'concept': 'new|en kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 26,
#      'in_conjunction_with_exact_avg_pos': 822.5,
#      'in_conjunction_with_conceptual_avg_pos': 647.4166666666666},
#     {'concept': 'new|en kindle|en',
#      'in_conjunction_with_count': 20,
#      'in_conjunction_with_exact_avg_pos': 81.57894736842105,
#      'in_conjunction_with_conceptual_avg_pos': -14.947368421052632},
#     {'concept': 'highly|en recommend|en',
#      'in_conjunction_with_count': 18,
#      'in_conjunction_with_exact_avg_pos': -275.3333333333333,
#      'in_conjunction_with_conceptual_avg_pos': 37.388888888888886},
#     {'concept': 'graphics|en',
#      'in_conjunction_with_count': 17,
#      'in_conjunction_with_exact_avg_pos': 117.0,
#      'in_conjunction_with_conceptual_avg_pos': 74.52941176470588},
#     {'concept': 'love|en kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 15,
#      'in_conjunction_with_exact_avg_pos': 482.7142857142857,
#      'in_conjunction_with_conceptual_avg_pos': 280.2857142857143},
#     {'concept': 'love|en kindle|en',
#      'in_conjunction_with_count': 12,
#      'in_conjunction_with_exact_avg_pos': 367.25,
#      'in_conjunction_with_conceptual_avg_pos': 0.0}]},
#   {'shared_concept_id': 'b49ceebc-8f7d-42e7-b49a-52f5e7400b92',
#    'name': 'email',
#    'texts': ['email'],
#    'color': '#808080',
#    'in_conjunction_with': [{'concept': 'kindle|en',
#      'in_conjunction_with_count': 1752,
#      'in_conjunction_with_exact_avg_pos': 33.816591879462486,
#      'in_conjunction_with_conceptual_avg_pos': 17.741999040246704},
#     {'concept': 'amazon|en',
#      'in_conjunction_with_count': 1462,
#      'in_conjunction_with_exact_avg_pos': -18.53736603636055,
#      'in_conjunction_with_conceptual_avg_pos': -24.60160649831582},
#     {'concept': 'device|en',
#      'in_conjunction_with_count': 1240,
#      'in_conjunction_with_exact_avg_pos': 15.122402962719418,
#      'in_conjunction_with_conceptual_avg_pos': 19.81087742075084},
#     {'concept': 'app|en',
#      'in_conjunction_with_count': 1154,
#      'in_conjunction_with_exact_avg_pos': -47.77974615580498,
#      'in_conjunction_with_conceptual_avg_pos': -11.264256901691159},
#     {'concept': 'book|en',
#      'in_conjunction_with_count': 957,
#      'in_conjunction_with_exact_avg_pos': -12.394148974998728,
#      'in_conjunction_with_conceptual_avg_pos': 36.726899414214685},
#     {'concept': 'read|en',
#      'in_conjunction_with_count': 821,
#      'in_conjunction_with_exact_avg_pos': 28.94186507936508,
#      'in_conjunction_with_conceptual_avg_pos': 44.458147900904905},
#     {'concept': 'tablet|en',
#      'in_conjunction_with_count': 811,
#      'in_conjunction_with_exact_avg_pos': 72.67186034660722,
#      'in_conjunction_with_conceptual_avg_pos': 8.237544354552552},
#     {'concept': 'buy|en',
#      'in_conjunction_with_count': 790,
#      'in_conjunction_with_exact_avg_pos': 15.998932656638136,
#      'in_conjunction_with_conceptual_avg_pos': 48.44448249619482},
#     {'concept': 'screen|en',
#      'in_conjunction_with_count': 681,
#      'in_conjunction_with_exact_avg_pos': 83.95313903339114,
#      'in_conjunction_with_conceptual_avg_pos': 62.19291716686675},
#     {'concept': 'purchase|en',
#      'in_conjunction_with_count': 518,
#      'in_conjunction_with_exact_avg_pos': 49.65880230880231,
#      'in_conjunction_with_conceptual_avg_pos': 60.125645342312005},
#     {'concept': 'kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 509,
#      'in_conjunction_with_exact_avg_pos': 139.09322344322345,
#      'in_conjunction_with_conceptual_avg_pos': 100.72521071777128},
#     {'concept': 'ipad|en',
#      'in_conjunction_with_count': 491,
#      'in_conjunction_with_exact_avg_pos': 72.10187074829932,
#      'in_conjunction_with_conceptual_avg_pos': 13.114656165496502},
#     {'concept': 'kindle|en fire|en',
#      'in_conjunction_with_count': 465,
#      'in_conjunction_with_exact_avg_pos': 148.40060109289618,
#      'in_conjunction_with_conceptual_avg_pos': 84.35491803278688},
#     {'concept': 'download|en',
#      'in_conjunction_with_count': 406,
#      'in_conjunction_with_exact_avg_pos': 39.10231481481482,
#      'in_conjunction_with_conceptual_avg_pos': 42.62358567358567},
#     {'concept': 'easy|en',
#      'in_conjunction_with_count': 363,
#      'in_conjunction_with_exact_avg_pos': -14.550717213114753,
#      'in_conjunction_with_conceptual_avg_pos': 16.753825136612026},
#     {'concept': 'charge|en',
#      'in_conjunction_with_count': 354,
#      'in_conjunction_with_exact_avg_pos': 1.0708020050125293,
#      'in_conjunction_with_conceptual_avg_pos': 22.94473684210526},
#     {'concept': 'movie|en',
#      'in_conjunction_with_count': 347,
#      'in_conjunction_with_exact_avg_pos': 2.9975589225589223,
#      'in_conjunction_with_conceptual_avg_pos': 16.919149831649833},
#     {'concept': 'sound|en',
#      'in_conjunction_with_count': 336,
#      'in_conjunction_with_exact_avg_pos': 111.19653880070547,
#      'in_conjunction_with_conceptual_avg_pos': 70.10385802469136},
#     {'concept': 'fire|en hd|en',
#      'in_conjunction_with_count': 332,
#      'in_conjunction_with_exact_avg_pos': 232.1923092998955,
#      'in_conjunction_with_conceptual_avg_pos': 33.34777429467085},
#     {'concept': 'product|en',
#      'in_conjunction_with_count': 312,
#      'in_conjunction_with_exact_avg_pos': 21.55627906976744,
#      'in_conjunction_with_conceptual_avg_pos': -41.63937984496124},
#     {'concept': 'hd|en',
#      'in_conjunction_with_count': 300,
#      'in_conjunction_with_exact_avg_pos': 105.8862760553512,
#      'in_conjunction_with_conceptual_avg_pos': 21.75602119460501},
#     {'concept': 'price|en',
#      'in_conjunction_with_count': 293,
#      'in_conjunction_with_exact_avg_pos': 35.63230787364451,
#      'in_conjunction_with_conceptual_avg_pos': 13.717055634134843},
#     {'concept': 'ad|en',
#      'in_conjunction_with_count': 292,
#      'in_conjunction_with_exact_avg_pos': 95.79793187347931,
#      'in_conjunction_with_conceptual_avg_pos': 1.6508796556241814},
#     {'concept': 'feature|en',
#      'in_conjunction_with_count': 281,
#      'in_conjunction_with_exact_avg_pos': 68.78770080321286,
#      'in_conjunction_with_conceptual_avg_pos': 40.821285140562246},
#     {'concept': 'review|en',
#      'in_conjunction_with_count': 259,
#      'in_conjunction_with_exact_avg_pos': 139.37664783427496,
#      'in_conjunction_with_conceptual_avg_pos': 36.27118644067796},
#     {'concept': 'camera|en',
#      'in_conjunction_with_count': 250,
#      'in_conjunction_with_exact_avg_pos': -59.62824829931973,
#      'in_conjunction_with_conceptual_avg_pos': 41.43341836734694},
#     {'concept': 'charger|en',
#      'in_conjunction_with_count': 243,
#      'in_conjunction_with_exact_avg_pos': -85.48412698412699,
#      'in_conjunction_with_conceptual_avg_pos': -34.56196581196581},
#     {'concept': 'update|en',
#      'in_conjunction_with_count': 238,
#      'in_conjunction_with_exact_avg_pos': -56.843485915492955,
#      'in_conjunction_with_conceptual_avg_pos': -48.63808685446009},
#     {'concept': 'computer|en',
#      'in_conjunction_with_count': 236,
#      'in_conjunction_with_exact_avg_pos': -44.0,
#      'in_conjunction_with_conceptual_avg_pos': 89.21696252465483},
#     {'concept': 'speaker|en',
#      'in_conjunction_with_count': 227,
#      'in_conjunction_with_exact_avg_pos': 243.13483796296296,
#      'in_conjunction_with_conceptual_avg_pos': 92.82291666666667},
#     {'concept': 'display|en',
#      'in_conjunction_with_count': 223,
#      'in_conjunction_with_exact_avg_pos': 140.29743265993267,
#      'in_conjunction_with_conceptual_avg_pos': 79.5413961038961},
#     {'concept': 'fast|en',
#      'in_conjunction_with_count': 211,
#      'in_conjunction_with_exact_avg_pos': 121.88943355119825,
#      'in_conjunction_with_conceptual_avg_pos': 9.471677559912854},
#     {'concept': 'wifi|en',
#      'in_conjunction_with_count': 208,
#      'in_conjunction_with_exact_avg_pos': 61.95614035087719,
#      'in_conjunction_with_conceptual_avg_pos': 5.076900584795322},
#     {'concept': 'read|en book|en',
#      'in_conjunction_with_count': 208,
#      'in_conjunction_with_exact_avg_pos': 25.723809523809525,
#      'in_conjunction_with_conceptual_avg_pos': 57.71714285714286},
#     {'concept': 'android|en',
#      'in_conjunction_with_count': 193,
#      'in_conjunction_with_exact_avg_pos': 22.622767857142858,
#      'in_conjunction_with_conceptual_avg_pos': -76.68630952380953},
#     {'concept': 'cloud|en',
#      'in_conjunction_with_count': 192,
#      'in_conjunction_with_exact_avg_pos': 97.66904761904762,
#      'in_conjunction_with_conceptual_avg_pos': 44.715126050420174},
#     {'concept': 'button|en',
#      'in_conjunction_with_count': 191,
#      'in_conjunction_with_exact_avg_pos': 18.59162087912088,
#      'in_conjunction_with_conceptual_avg_pos': -107.94310897435898},
#     {'concept': 'laptop|en',
#      'in_conjunction_with_count': 171,
#      'in_conjunction_with_exact_avg_pos': 62.58974358974359,
#      'in_conjunction_with_conceptual_avg_pos': -79.16153846153846},
#     {'concept': 'keyboard|en',
#      'in_conjunction_with_count': 159,
#      'in_conjunction_with_exact_avg_pos': 80.5143115942029,
#      'in_conjunction_with_conceptual_avg_pos': 16.879981884057973},
#     {'concept': 'customer|en',
#      'in_conjunction_with_count': 158,
#      'in_conjunction_with_exact_avg_pos': -127.66137566137566,
#      'in_conjunction_with_conceptual_avg_pos': -36.81613756613756},
#     {'concept': 'reader|en',
#      'in_conjunction_with_count': 158,
#      'in_conjunction_with_exact_avg_pos': 97.16544342507645,
#      'in_conjunction_with_conceptual_avg_pos': 97.5137614678899},
#     {'concept': 'amazon|en prime|en',
#      'in_conjunction_with_count': 156,
#      'in_conjunction_with_exact_avg_pos': 125.044,
#      'in_conjunction_with_conceptual_avg_pos': 92.77466666666666},
#     {'concept': 'skype|en',
#      'in_conjunction_with_count': 154,
#      'in_conjunction_with_exact_avg_pos': -15.71218487394958,
#      'in_conjunction_with_conceptual_avg_pos': -50.785714285714285},
#     {'concept': 'web|en',
#      'in_conjunction_with_count': 151,
#      'in_conjunction_with_exact_avg_pos': 92.90785907859079,
#      'in_conjunction_with_conceptual_avg_pos': -30.665311653116532},
#     {'concept': 'option|en',
#      'in_conjunction_with_count': 148,
#      'in_conjunction_with_exact_avg_pos': 55.94471153846154,
#      'in_conjunction_with_conceptual_avg_pos': -10.315705128205128},
#     {'concept': 'watch|en movie|en',
#      'in_conjunction_with_count': 146,
#      'in_conjunction_with_exact_avg_pos': -100.01,
# ...
#      'in_conjunction_with_exact_avg_pos': 272.3777777777778,
#      'in_conjunction_with_conceptual_avg_pos': 138.57662037037036},
#     {'concept': 'download|en',
#      'in_conjunction_with_count': 167,
#      'in_conjunction_with_exact_avg_pos': 10.927083333333334,
#      'in_conjunction_with_conceptual_avg_pos': 183.77765151515152},
#     {'concept': 'price|en',
#      'in_conjunction_with_count': 156,
#      'in_conjunction_with_exact_avg_pos': -44.760128205128204,
#      'in_conjunction_with_conceptual_avg_pos': -24.633214285714285},
#     {'concept': 'fast|en',
#      'in_conjunction_with_count': 154,
#      'in_conjunction_with_exact_avg_pos': 134.98739495798318,
#      'in_conjunction_with_conceptual_avg_pos': 2.2464985994397733},
#     {'concept': 'charger|en',
#      'in_conjunction_with_count': 148,
#      'in_conjunction_with_exact_avg_pos': 163.42965367965368,
#      'in_conjunction_with_conceptual_avg_pos': -12.602504638218926},
#     {'concept': 'sound|en',
#      'in_conjunction_with_count': 147,
#      'in_conjunction_with_exact_avg_pos': 160.20462962962964,
#      'in_conjunction_with_conceptual_avg_pos': 86.92222222222222},
#     {'concept': 'movie|en',
#      'in_conjunction_with_count': 143,
#      'in_conjunction_with_exact_avg_pos': 60.51210317460317,
#      'in_conjunction_with_conceptual_avg_pos': 125.8452380952381},
#     {'concept': 'easy|en',
#      'in_conjunction_with_count': 141,
#      'in_conjunction_with_exact_avg_pos': 121.06990740740741,
#      'in_conjunction_with_conceptual_avg_pos': -2.407407407407401},
#     {'concept': 'ad|en',
#      'in_conjunction_with_count': 138,
#      'in_conjunction_with_exact_avg_pos': 171.8721794871795,
#      'in_conjunction_with_conceptual_avg_pos': -46.788717948717945},
#     {'concept': 'hd|en',
#      'in_conjunction_with_count': 135,
#      'in_conjunction_with_exact_avg_pos': 308.2609126984127,
#      'in_conjunction_with_conceptual_avg_pos': 77.89583333333333},
#     {'concept': 'review|en',
#      'in_conjunction_with_count': 122,
#      'in_conjunction_with_exact_avg_pos': 309.3270042194093,
#      'in_conjunction_with_conceptual_avg_pos': 118.90717299578058},
#     {'concept': 'feature|en',
#      'in_conjunction_with_count': 120,
#      'in_conjunction_with_exact_avg_pos': 78.55,
#      'in_conjunction_with_conceptual_avg_pos': -12.7265625},
#     {'concept': 'item|en',
#      'in_conjunction_with_count': 112,
#      'in_conjunction_with_exact_avg_pos': -2.6620370370370376,
#      'in_conjunction_with_conceptual_avg_pos': 92.41435185185185},
#     {'concept': 'amazon|en prime|en',
#      'in_conjunction_with_count': 109,
#      'in_conjunction_with_exact_avg_pos': 151.2690763052209,
#      'in_conjunction_with_conceptual_avg_pos': 48.28714859437751},
#     {'concept': 'wifi|en',
#      'in_conjunction_with_count': 104,
#      'in_conjunction_with_exact_avg_pos': 270.22264150943397,
#      'in_conjunction_with_conceptual_avg_pos': -98.07610062893082},
#     {'concept': 'camera|en',
#      'in_conjunction_with_count': 101,
#      'in_conjunction_with_exact_avg_pos': -149.03688230008984,
#      'in_conjunction_with_conceptual_avg_pos': 152.1543126684636},
#     {'concept': 'speaker|en',
#      'in_conjunction_with_count': 100,
#      'in_conjunction_with_exact_avg_pos': 281.88709677419354,
#      'in_conjunction_with_conceptual_avg_pos': 149.7741935483871},
#     {'concept': 'android|en',
#      'in_conjunction_with_count': 99,
#      'in_conjunction_with_exact_avg_pos': -114.96078431372548,
#      'in_conjunction_with_conceptual_avg_pos': 8.820261437908497},
#     {'concept': 'update|en',
#      'in_conjunction_with_count': 91,
#      'in_conjunction_with_exact_avg_pos': -8.504432624113475,
#      'in_conjunction_with_conceptual_avg_pos': 27.27304964539007},
#     {'concept': 'christmas|en',
#      'in_conjunction_with_count': 90,
#      'in_conjunction_with_exact_avg_pos': 132.15740740740742,
#      'in_conjunction_with_conceptual_avg_pos': 190.15740740740742},
#     {'concept': 'display|en',
#      'in_conjunction_with_count': 89,
#      'in_conjunction_with_exact_avg_pos': 97.07156084656086,
#      'in_conjunction_with_conceptual_avg_pos': 70.15895061728395},
#     {'concept': 'button|en',
#      'in_conjunction_with_count': 88,
#      'in_conjunction_with_exact_avg_pos': -67.2421568627451,
#      'in_conjunction_with_conceptual_avg_pos': -113.5921568627451},
#     {'concept': 'cloud|en',
#      'in_conjunction_with_count': 88,
#      'in_conjunction_with_exact_avg_pos': -161.2312925170068,
#      'in_conjunction_with_conceptual_avg_pos': -66.01836734693877},
#     {'concept': 'computer|en',
#      'in_conjunction_with_count': 84,
#      'in_conjunction_with_exact_avg_pos': 242.17176870748298,
#      'in_conjunction_with_conceptual_avg_pos': 329.8962585034013},
#     {'concept': 'plug|en',
#      'in_conjunction_with_count': 84,
#      'in_conjunction_with_exact_avg_pos': -65.17517006802721,
#      'in_conjunction_with_conceptual_avg_pos': -23.70068027210884},
#     {'concept': 'email|en',
#      'in_conjunction_with_count': 83,
#      'in_conjunction_with_exact_avg_pos': -37.30172413793103,
#      'in_conjunction_with_conceptual_avg_pos': 88.37931034482759},
#     {'concept': 'customer|en',
#      'in_conjunction_with_count': 74,
#      'in_conjunction_with_exact_avg_pos': 71.8858024691358,
#      'in_conjunction_with_conceptual_avg_pos': -55.858024691358025},
#     {'concept': 'enjoy|en',
#      'in_conjunction_with_count': 74,
#      'in_conjunction_with_exact_avg_pos': 167.9,
#      'in_conjunction_with_conceptual_avg_pos': 113.94242424242424},
#     {'concept': 'nexus|en 7|en',
#      'in_conjunction_with_count': 73,
#      'in_conjunction_with_exact_avg_pos': -251.31728395061728,
#      'in_conjunction_with_conceptual_avg_pos': -291.3641975308642},
#     {'concept': 'gift|en',
#      'in_conjunction_with_count': 71,
#      'in_conjunction_with_exact_avg_pos': 216.16959064327486,
#      'in_conjunction_with_conceptual_avg_pos': 80.91228070175438},
#     {'concept': 'customer|en service|en',
#      'in_conjunction_with_count': 69,
#      'in_conjunction_with_exact_avg_pos': -97.79069767441861,
#      'in_conjunction_with_conceptual_avg_pos': -39.98837209302326},
#     {'concept': 'option|en',
#      'in_conjunction_with_count': 68,
#      'in_conjunction_with_exact_avg_pos': 97.62943262411348,
#      'in_conjunction_with_conceptual_avg_pos': 132.75886524822695},
#     {'concept': 'apple|en',
#      'in_conjunction_with_count': 66,
#      'in_conjunction_with_exact_avg_pos': -168.75333333333333,
#      'in_conjunction_with_conceptual_avg_pos': -265.2274074074074},
#     {'concept': 'stream|en',
#      'in_conjunction_with_count': 66,
#      'in_conjunction_with_exact_avg_pos': 176.94444444444446,
#      'in_conjunction_with_conceptual_avg_pos': 253.53968253968253},
#     {'concept': 'kindle|en fire|en hd|en 7|en',
#      'in_conjunction_with_count': 65,
#      'in_conjunction_with_exact_avg_pos': 222.79,
#      'in_conjunction_with_conceptual_avg_pos': 400.35},
#     {'concept': 'keyboard|en',
#      'in_conjunction_with_count': 64,
#      'in_conjunction_with_exact_avg_pos': 283.43910256410254,
#      'in_conjunction_with_conceptual_avg_pos': -70.48397435897436},
#     {'concept': 'read|en book|en',
#      'in_conjunction_with_count': 64,
#      'in_conjunction_with_exact_avg_pos': 97.83,
#      'in_conjunction_with_conceptual_avg_pos': 338.82},
#     {'concept': 'netflix|en',
#      'in_conjunction_with_count': 62,
#      'in_conjunction_with_exact_avg_pos': 222.78095238095239,
#      'in_conjunction_with_conceptual_avg_pos': 124.1468253968254},
#     {'concept': 'reader|en',
#      'in_conjunction_with_count': 61,
#      'in_conjunction_with_exact_avg_pos': 157.87626262626262,
#      'in_conjunction_with_conceptual_avg_pos': 20.532467532467532},
#     {'concept': 'watch|en movie|en',
#      'in_conjunction_with_count': 61,
#      'in_conjunction_with_exact_avg_pos': 149.2826086956522,
#      'in_conjunction_with_conceptual_avg_pos': 311.2173913043478},
#     {'concept': 'carousel|en',
#      'in_conjunction_with_count': 60,
#      'in_conjunction_with_exact_avg_pos': 283.21505376344084,
#      'in_conjunction_with_conceptual_avg_pos': 168.66666666666666},
#     {'concept': 'laptop|en',
#      'in_conjunction_with_count': 60,
#      'in_conjunction_with_exact_avg_pos': 290.76428571428573,
#      'in_conjunction_with_conceptual_avg_pos': -32.595238095238095},
#     {'concept': 'connect|en',
#      'in_conjunction_with_count': 60,
#      'in_conjunction_with_exact_avg_pos': 210.4078947368421,
#      'in_conjunction_with_conceptual_avg_pos': 48.078947368421055},
#     {'concept': 'user|en',
#      'in_conjunction_with_count': 59,
#      'in_conjunction_with_exact_avg_pos': 150.87403100775194,
#      'in_conjunction_with_conceptual_avg_pos': -54.515503875968996},
#     {'concept': 'compare|en',
#      'in_conjunction_with_count': 59,
#      'in_conjunction_with_exact_avg_pos': 336.06382978723406,
#      'in_conjunction_with_conceptual_avg_pos': 270.29432624113474},
#     {'concept': 'load|en',
#      'in_conjunction_with_count': 57,
#      'in_conjunction_with_exact_avg_pos': 114.29583333333333,
#      'in_conjunction_with_conceptual_avg_pos': 108.80833333333334},
#     {'concept': 'color|en',
#      'in_conjunction_with_count': 56,
#      'in_conjunction_with_exact_avg_pos': 142.5,
#      'in_conjunction_with_conceptual_avg_pos': 111.90625},
#     {'concept': 'excellent|en',
#      'in_conjunction_with_count': 55,
#      'in_conjunction_with_exact_avg_pos': -46.05952380952381,
#      'in_conjunction_with_conceptual_avg_pos': 66.30952380952381},
#     {'concept': 'iphone|en',
#      'in_conjunction_with_count': 52,
#      'in_conjunction_with_exact_avg_pos': 250.18027210884355,
#      'in_conjunction_with_conceptual_avg_pos': -13.821428571428571},
#     {'concept': 'kindle|en hd|en',
#      'in_conjunction_with_count': 51,
#      'in_conjunction_with_exact_avg_pos': 526.1616161616162,
#      'in_conjunction_with_conceptual_avg_pos': 51.388888888888886},
#     {'concept': 'install|en',
#      'in_conjunction_with_count': 49,
#      'in_conjunction_with_exact_avg_pos': -257.75,
#      'in_conjunction_with_conceptual_avg_pos': 22.735119047619055},
#     {'concept': 'skype|en',
#      'in_conjunction_with_count': 49,
#      'in_conjunction_with_exact_avg_pos': -228.5,
#      'in_conjunction_with_conceptual_avg_pos': -175.25462962962962},
#     {'concept': 'magazine|en',
#      'in_conjunction_with_count': 48,
#      'in_conjunction_with_exact_avg_pos': 72.22066326530613,
#      'in_conjunction_with_conceptual_avg_pos': 242.39285714285714},
#     {'concept': 'ipad|en mini|en',
#      'in_conjunction_with_count': 48,
#      'in_conjunction_with_exact_avg_pos': 87.32051282051282,
#      'in_conjunction_with_conceptual_avg_pos': -94.73076923076923},
#     {'concept': 'recommend|en',
#      'in_conjunction_with_count': 48,
#      'in_conjunction_with_exact_avg_pos': -299.30555555555554,
#      'in_conjunction_with_conceptual_avg_pos': -159.0},
#     {'concept': 'awesome|en',
#      'in_conjunction_with_count': 48,
#      'in_conjunction_with_exact_avg_pos': 341.5701754385965,
#      'in_conjunction_with_conceptual_avg_pos': 178.89473684210526},
#     {'concept': 'annoy|en',
#      'in_conjunction_with_count': 46,
#      'in_conjunction_with_exact_avg_pos': -106.48095238095239,
#      'in_conjunction_with_conceptual_avg_pos': 142.74285714285713},
#     {'concept': 'cheap|en',
#      'in_conjunction_with_count': 45,
#      'in_conjunction_with_exact_avg_pos': 210.61290322580646,
#      'in_conjunction_with_conceptual_avg_pos': 88.73118279569893},
#     {'concept': 'browser|en',
#      'in_conjunction_with_count': 44,
#      'in_conjunction_with_exact_avg_pos': -96.62820512820514,
#      'in_conjunction_with_conceptual_avg_pos': 11.211538461538462},
#     {'concept': 'upgrade|en',
#      'in_conjunction_with_count': 42,
#      'in_conjunction_with_exact_avg_pos': 443.4117647058824,
#      'in_conjunction_with_conceptual_avg_pos': 415.5882352941176},
#     {'concept': 'complaint|en',
#      'in_conjunction_with_count': 40,
#      'in_conjunction_with_exact_avg_pos': 31.955882352941178,
#      'in_conjunction_with_conceptual_avg_pos': -212.13235294117646},
#     {'concept': 'battery|en life|en',
#      'in_conjunction_with_count': 40,
#      'in_conjunction_with_exact_avg_pos': 222.56060606060606,
#      'in_conjunction_with_conceptual_avg_pos': 194.5},
#     {'concept': 'flash|en',
#      'in_conjunction_with_count': 39,
#      'in_conjunction_with_exact_avg_pos': -193.74603174603175,
#      'in_conjunction_with_conceptual_avg_pos': 607.6825396825396},
#     {'concept': 'new|en kindle|en',
#      'in_conjunction_with_count': 38,
#      'in_conjunction_with_exact_avg_pos': 21.580645161290324,
#      'in_conjunction_with_conceptual_avg_pos': 133.96774193548387},
#     {'concept': 'web|en',
#      'in_conjunction_with_count': 38,
#      'in_conjunction_with_exact_avg_pos': -232.14285714285714,
#      'in_conjunction_with_conceptual_avg_pos': -11.851190476190476},
#     {'concept': 'battery|en',
#      'in_conjunction_with_count': 36,
#      'in_conjunction_with_exact_avg_pos': -164.53571428571428,
#      'in_conjunction_with_conceptual_avg_pos': 211.0},
#     {'concept': 'pro|en',
#      'in_conjunction_with_count': 35,
#      'in_conjunction_with_exact_avg_pos': 342.632,
#      'in_conjunction_with_conceptual_avg_pos': 544.52},
#     {'concept': 'nook|en',
#      'in_conjunction_with_count': 34,
#      'in_conjunction_with_exact_avg_pos': -344.3809523809524,
#      'in_conjunction_with_conceptual_avg_pos': 180.18095238095233},
#     {'concept': 'wi-fi|en',
#      'in_conjunction_with_count': 34,
#      'in_conjunction_with_exact_avg_pos': 245.09027777777777,
#      'in_conjunction_with_conceptual_avg_pos': 567.1388888888889},
#     {'concept': 'improvement|en',
#      'in_conjunction_with_count': 32,
#      'in_conjunction_with_exact_avg_pos': -126.65079365079364,
#      'in_conjunction_with_conceptual_avg_pos': -314.3809523809524},
#     {'concept': 'replace|en',
#      'in_conjunction_with_count': 30,
#      'in_conjunction_with_exact_avg_pos': 28.28,
#      'in_conjunction_with_conceptual_avg_pos': -80.62},
#     {'concept': 'con|en',
#      'in_conjunction_with_count': 30,
#      'in_conjunction_with_exact_avg_pos': 213.85,
#      'in_conjunction_with_conceptual_avg_pos': 717.6333333333333},
#     {'concept': 'browse|en',
#      'in_conjunction_with_count': 29,
#      'in_conjunction_with_exact_avg_pos': -432.7291666666667,
#      'in_conjunction_with_conceptual_avg_pos': 35.541666666666664},
#     {'concept': 'advertise|en',
#      'in_conjunction_with_count': 29,
#      'in_conjunction_with_exact_avg_pos': -97.12,
#      'in_conjunction_with_conceptual_avg_pos': 161.66},
#     {'concept': 'highly|en recommend|en',
#      'in_conjunction_with_count': 24,
#      'in_conjunction_with_exact_avg_pos': -42.26086956521739,
#      'in_conjunction_with_conceptual_avg_pos': 42.30434782608695},
#     {'concept': 'audio|en',
#      'in_conjunction_with_count': 24,
#      'in_conjunction_with_exact_avg_pos': 304.33333333333337,
#      'in_conjunction_with_conceptual_avg_pos': 90.03125},
#     {'concept': 'original|en kindle|en fire|en',
#      'in_conjunction_with_count': 16,
#      'in_conjunction_with_exact_avg_pos': 1151.4666666666667,
#      'in_conjunction_with_conceptual_avg_pos': 0.0},
#     {'concept': 'new|en kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 14,
#      'in_conjunction_with_exact_avg_pos': 110.85714285714286,
#      'in_conjunction_with_conceptual_avg_pos': 964.2857142857143},
#     {'concept': 'old|en kindle|en',
#      'in_conjunction_with_count': 14,
#      'in_conjunction_with_exact_avg_pos': 196.66666666666666,
#      'in_conjunction_with_conceptual_avg_pos': -67.83333333333333},
#     {'concept': 'love|en kindle|en',
#      'in_conjunction_with_count': 12,
#      'in_conjunction_with_exact_avg_pos': 203.83333333333334,
#      'in_conjunction_with_conceptual_avg_pos': 186.83333333333334},
#     {'concept': 'graphics|en',
#      'in_conjunction_with_count': 10,
#      'in_conjunction_with_exact_avg_pos': 249.04166666666666,
#      'in_conjunction_with_conceptual_avg_pos': 0.0},
#     {'concept': 'love|en kindle|en fire|en hd|en',
#      'in_conjunction_with_count': 9,
#      'in_conjunction_with_exact_avg_pos': 1316.5555555555557,
#      'in_conjunction_with_conceptual_avg_pos': 493.77777777777777}]}]}

# %%
# flatten out the concepts
export_data = []
for cl in concept_lists:
    for c in cl['concepts']:
        for icw in c['in_conjunction_with']:
            export_data.append({
                'saved_concept_list': cl['name'],
                'saved_concept': c['name'],
                'icw_concept': icw['concept'],
                'icw_count': icw['in_conjunction_with_count'],
                'icw_exact_avg_pos': icw['in_conjunction_with_exact_avg_pos'],
                'icw_conceptual_avg_pos': icw['in_conjunction_with_conceptual_avg_pos']
                })

# %%
export_data[0]
# Out:
# {'saved_concept_list': 'cluster7x4',
#  'saved_concept': 'download',
#  'icw_concept': 'kindle|en',
#  'icw_count': 1555,
#  'icw_exact_avg_pos': 55.622244135992126,
#  'icw_conceptual_avg_pos': -0.053832146437108055}

# %%
# write csv sample
# output the labeled results

# when you need a calculated list of fields
# fields = list(set(val for dic in result_data for val in dic.keys())) 
output_csv_file = "output.csv"
fields = export_data[0].keys()
with open(output_csv_file, 'w') as f:
        writer = csv.DictWriter(f, fields)
        writer.writeheader()
        writer.writerows(export_data)
